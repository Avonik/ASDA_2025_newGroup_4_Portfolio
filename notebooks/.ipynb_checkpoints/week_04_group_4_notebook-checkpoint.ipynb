# %% [markdown]
# # Airbnb Europe
# <div style="
#     border: 5px solid purple;
#     border-radius: 8px;
#     padding: 0px;
#     margin: 10px 0;
#     background-color: inherit;
#     color: inherit;
# ">
# </div>

# %% [markdown]
# ### Libraries Loading
# <div style="
#     border: 2px solid orange;
#     border-radius: 8px;
#     padding: 0px;
#     margin: 10px 0;
#     background-color: inherit;
#     color: inherit;
# ">
# </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Data wrangling
# <div style="
#     border: 2px solid orange;
#     border-radius: 8px;
#     padding: 0px;
#     margin: 10px 0;
#     background-color: inherit;
#     color: inherit;
# ">
# </div>

# %%
url = "https://docs.google.com/spreadsheets/d/1ecopK6oyyb4d_7-QLrCr8YlgFrCetHU7-VQfnYej7JY/export?format=xlsx"
dataset = pd.ExcelFile(url, engine='openpyxl')

# %%
dataset = pd.concat([dataset.parse(sheet_name).assign(sheet_name = sheet_name) for sheet_name in dataset.sheet_names])
dataset.reset_index(inplace = True)

dataset.sheet_name
# Out:
# 0        amsterdam_weekdays
# 1        amsterdam_weekdays
# 2        amsterdam_weekdays
# 3        amsterdam_weekdays
# 4        amsterdam_weekdays
#                 ...
# 51702       vienna_weekends
# 51703       vienna_weekends
# 51704       vienna_weekends
# 51705       vienna_weekends
# 51706       vienna_weekends
# Name: sheet_name, Length: 51707, dtype: object

# %%
dataset.head(10)
# Out:
#    index  Unnamed: 0      realSum        room_type  room_shared  room_private  \
# 0      0           0   194.033698     Private room        False          True
# 1      1           1   344.245776     Private room        False          True
# 2      2           2   264.101422     Private room        False          True
# 3      3           3   433.529398     Private room        False          True
# 4      4           4   485.552926     Private room        False          True
# 5      5           5   552.808567     Private room        False          True
# 6      6           6   215.124317     Private room        False          True
# 7      7           7  2771.307384  Entire home/apt        False         False
# 8      8           8  1001.804420  Entire home/apt        False         False
# 9      9           9   276.521454     Private room        False          True
#
#    person_capacity  host_is_superhost  multi  biz  ...  bedrooms      dist  \
# 0                2              False      1    0  ...         1  5.022964
# 1                4              False      0    0  ...         1  0.488389
# 2                2              False      0    1  ...         1  5.748312
# 3                4              False      0    1  ...         2  0.384862
# 4                2               True      0    0  ...         1  0.544738
# 5                3              False      0    0  ...         2  2.131420
# 6                2              False      0    0  ...         1  1.881092
# 7                4               True      0    0  ...         3  1.686807
# 8                4              False      0    0  ...         2  3.719141
# 9                2              False      1    0  ...         1  3.142361
#
#    metro_dist  attr_index  attr_index_norm  rest_index  rest_index_norm  \
# 0    2.539380   78.690379         4.166708   98.253896         6.846473
# 1    0.239404  631.176378        33.421209  837.280757        58.342928
# 2    3.651621   75.275877         3.985908   95.386955         6.646700
# 3    0.439876  493.272534        26.119108  875.033098        60.973565
# 4    0.318693  552.830324        29.272733  815.305740        56.811677
# 5    1.904668  174.788957         9.255191  225.201662        15.692376
# 6    0.729747  200.167652        10.599010  242.765524        16.916251
# 7    1.458404  208.808109        11.056528  272.313823        18.975219
# 8    1.196112  106.226456         5.624761  133.876202         9.328686
# 9    0.924404  206.252862        10.921226  238.291258        16.604478
#
#        lng       lat          sheet_name
# 0  4.90569  52.41772  amsterdam_weekdays
# 1  4.90005  52.37432  amsterdam_weekdays
# 2  4.97512  52.36103  amsterdam_weekdays
# 3  4.89417  52.37663  amsterdam_weekdays
# 4  4.90051  52.37508  amsterdam_weekdays
# 5  4.87699  52.38966  amsterdam_weekdays
# 6  4.91570  52.38296  amsterdam_weekdays
# 7  4.88467  52.38749  amsterdam_weekdays
# 8  4.86459  52.40175  amsterdam_weekdays
# 9  4.87600  52.34700  amsterdam_weekdays
#
# [10 rows x 22 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51707 entries, 0 to 51706
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   index                       51707 non-null  int64
#  1   Unnamed: 0                  51707 non-null  int64
#  2   realSum                     51707 non-null  float64
#  3   room_type                   51707 non-null  object
#  4   room_shared                 51707 non-null  bool
#  5   room_private                51707 non-null  bool
#  6   person_capacity             51707 non-null  int64
#  7   host_is_superhost           51707 non-null  bool
#  8   multi                       51707 non-null  int64
#  9   biz                         51707 non-null  int64
#  10  cleanliness_rating          51707 non-null  int64
#  11  guest_satisfaction_overall  51707 non-null  int64
#  12  bedrooms                    51707 non-null  int64
#  13  dist                        51707 non-null  float64
#  14  metro_dist                  51707 non-null  float64
#  15  attr_index                  51707 non-null  float64
#  16  attr_index_norm             51707 non-null  float64
#  17  rest_index                  51707 non-null  float64
#  18  rest_index_norm             51707 non-null  float64
#  19  lng                         51707 non-null  float64
#  20  lat                         51707 non-null  float64
#  21  sheet_name                  51707 non-null  object
# dtypes: bool(3), float64(9), int64(8), object(2)
# memory usage: 7.6+ MB

# %%
# rename name
dataset.rename(columns={'realSum': 'Price'}, inplace=True)
dataset.head()
# Out:
#    index  Unnamed: 0       Price     room_type  room_shared  room_private  \
# 0      0           0  194.033698  Private room        False          True
# 1      1           1  344.245776  Private room        False          True
# 2      2           2  264.101422  Private room        False          True
# 3      3           3  433.529398  Private room        False          True
# 4      4           4  485.552926  Private room        False          True
#
#    person_capacity  host_is_superhost  multi  biz  ...  bedrooms      dist  \
# 0                2              False      1    0  ...         1  5.022964
# 1                4              False      0    0  ...         1  0.488389
# 2                2              False      0    1  ...         1  5.748312
# 3                4              False      0    1  ...         2  0.384862
# 4                2               True      0    0  ...         1  0.544738
#
#    metro_dist  attr_index  attr_index_norm  rest_index  rest_index_norm  \
# 0    2.539380   78.690379         4.166708   98.253896         6.846473
# 1    0.239404  631.176378        33.421209  837.280757        58.342928
# 2    3.651621   75.275877         3.985908   95.386955         6.646700
# 3    0.439876  493.272534        26.119108  875.033098        60.973565
# 4    0.318693  552.830324        29.272733  815.305740        56.811677
#
#        lng       lat          sheet_name
# 0  4.90569  52.41772  amsterdam_weekdays
# 1  4.90005  52.37432  amsterdam_weekdays
# 2  4.97512  52.36103  amsterdam_weekdays
# 3  4.89417  52.37663  amsterdam_weekdays
# 4  4.90051  52.37508  amsterdam_weekdays
#
# [5 rows x 22 columns]

# %%
# drop unnamed : 0 column in dataset
dataset = dataset.drop("Unnamed: 0", axis=1)
dataset.head()
# Out:
#    index       Price     room_type  room_shared  room_private  \
# 0      0  194.033698  Private room        False          True
# 1      1  344.245776  Private room        False          True
# 2      2  264.101422  Private room        False          True
# 3      3  433.529398  Private room        False          True
# 4      4  485.552926  Private room        False          True
#
#    person_capacity  host_is_superhost  multi  biz  cleanliness_rating  ...  \
# 0                2              False      1    0                  10  ...
# 1                4              False      0    0                   8  ...
# 2                2              False      0    1                   9  ...
# 3                4              False      0    1                   9  ...
# 4                2               True      0    0                  10  ...
#
#    bedrooms      dist  metro_dist  attr_index  attr_index_norm  rest_index  \
# 0         1  5.022964    2.539380   78.690379         4.166708   98.253896
# 1         1  0.488389    0.239404  631.176378        33.421209  837.280757
# 2         1  5.748312    3.651621   75.275877         3.985908   95.386955
# 3         2  0.384862    0.439876  493.272534        26.119108  875.033098
# 4         1  0.544738    0.318693  552.830324        29.272733  815.305740
#
#    rest_index_norm      lng       lat          sheet_name
# 0         6.846473  4.90569  52.41772  amsterdam_weekdays
# 1        58.342928  4.90005  52.37432  amsterdam_weekdays
# 2         6.646700  4.97512  52.36103  amsterdam_weekdays
# 3        60.973565  4.89417  52.37663  amsterdam_weekdays
# 4        56.811677  4.90051  52.37508  amsterdam_weekdays
#
# [5 rows x 21 columns]

# %%
dataset[['city', 'weekday']] = dataset["sheet_name"].str.split('_', expand = True)

dataset.sample(10)
# Out:
#        index       Price        room_type  room_shared  room_private  \
# 16599   1848  168.021808  Entire home/apt        False         False
# 42122   2979   99.127955     Private room        False          True
# 14976    225  134.417446  Entire home/apt        False         False
# 47777   4142  208.075188  Entire home/apt        False         False
# 49905   1735  251.501765  Entire home/apt        False         False
# 1875     772  539.216835     Private room        False          True
# 37306   1721  382.374872  Entire home/apt        False         False
# 43721     86   92.114184     Private room        False          True
# 12816    139  154.392067  Entire home/apt        False         False
# 21407   1851  235.928705  Entire home/apt        False         False
#
#        person_capacity  host_is_superhost  multi  biz  cleanliness_rating  \
# 16599                4              False      0    1                  10
# 42122                2               True      1    0                  10
# 14976                3              False      0    0                   8
# 47777                4              False      0    1                  10
# 49905                2              False      0    0                   8
# 1875                 3               True      1    0                  10
# 37306                3              False      0    0                   7
# 43721                2              False      1    0                  10
# 12816                4               True      1    0                  10
# 21407                4              False      1    0                  10
#
#        ...  metro_dist  attr_index  attr_index_norm   rest_index  \
# 16599  ...    0.247697  119.365380         7.124194   211.408028
# 42122  ...    0.448671  324.263324         7.185739   806.618593
# 14976  ...    0.167046  194.426523        11.604138   673.529617
# 47777  ...    1.787985  589.308665        13.056395  2747.331857
# 49905  ...    0.100844  204.967222        14.678876   342.177253
# 1875   ...    0.582055   99.661197         5.276604   124.359026
# 37306  ...    0.075529  296.001073        14.393074   755.307403
# 43721  ...    0.132506  411.259441         9.111635   954.125810
# 12816  ...    0.445795  262.231468        15.638095   502.237767
# 21407  ...    0.379378  122.049440         4.025589   371.747671
#
#        rest_index_norm       lng       lat          sheet_name       city  \
# 16599        18.480856  19.05064  47.47788   budapest_weekends   budapest
# 42122        17.562358  12.48701  41.87373       rome_weekdays       rome
# 14976        58.878578  19.06910  47.49804   budapest_weekends   budapest
# 47777        59.857696  12.46922  41.89135       rome_weekends       rome
# 49905         8.179995  16.38070  48.20296     vienna_weekdays     vienna
# 1875         10.841122   4.82587  52.35903  amsterdam_weekends  amsterdam
# 37306        34.844092   2.36204  48.87901      paris_weekends      paris
# 43721        20.788087  12.50800  41.89100       rome_weekends       rome
# 12816        38.030989  19.05622  47.50739   budapest_weekdays   budapest
# 21407        20.893202  -9.13607  38.73031     lisbon_weekends     lisbon
#
#         weekday
# 16599  weekends
# 42122  weekdays
# 14976  weekends
# 47777  weekends
# 49905  weekdays
# 1875   weekends
# 37306  weekends
# 43721  weekends
# 12816  weekdays
# 21407  weekends
#
# [10 rows x 23 columns]

# %%
# unique city
dataset["city"].unique()
# Out:
# array(['amsterdam', 'athens', 'berlin', 'barcelona', 'budapest', 'lisbon',
#        'london', 'paris', 'rome', 'vienna'], dtype=object)

# %%
dataset["weekday"].unique()
# Out:
# array(['weekdays', 'weekends'], dtype=object)

# %%
dataset['weekday'] = dataset['weekday'].map({'weekdays': 0, 'weekends': 1})
dataset.sample(10)
# Out:
#        index       Price        room_type  room_shared  room_private  \
# 16483   1732  125.252620  Entire home/apt        False         False
# 31489   4413  698.511254  Entire home/apt        False         False
# 770      770  647.482014  Entire home/apt        False         False
# 46538   2903  286.629416  Entire home/apt        False         False
# 6786    2053  254.962154  Entire home/apt        False         False
# 30888   3812  104.894283     Private room        False          True
# 26535   4073  582.092711  Entire home/apt        False         False
# 13127    450  234.525544  Entire home/apt        False         False
# 29608   2532  158.517369     Private room        False          True
# 42879   3736  125.780282     Private room        False          True
#
#        person_capacity  host_is_superhost  multi  biz  cleanliness_rating  \
# 16483                4               True      1    0                  10
# 31489                4              False      1    0                   9
# 770                  3              False      0    1                  10
# 46538                6               True      1    0                   9
# 6786                 4               True      0    0                  10
# 30888                2              False      0    0                  10
# 26535                6              False      0    0                  10
# 13127                4              False      1    0                  10
# 29608                3              False      1    0                   9
# 42879                2               True      0    0                  10
#
#        ...  metro_dist  attr_index  attr_index_norm   rest_index  \
# 16483  ...    0.616882  104.114427         6.213958   184.588510
# 31489  ...    0.039162  478.289138        33.247743   789.305192
# 770    ...    0.568921  343.360107        18.181146   402.133500
# 46538  ...    0.287571  552.835200        12.248309  1341.869801
# 6786   ...    0.591577  167.502738         6.311124   190.078739
# 30888  ...    0.359237  147.509065        10.253930   323.029251
# 26535  ...    2.975397  110.743425         7.697898   235.072756
# 13127  ...    0.672250  177.252156        10.570379   215.265850
# 29608  ...    0.554968  409.258266        28.449138   652.766713
# 42879  ...    0.731340  341.747278         7.573187   914.014379
#
#        rest_index_norm       lng       lat          sheet_name       city  \
# 16483        16.136349  19.05500  47.47500   budapest_weekends   budapest
# 31489        14.127188  -0.13386  51.48956     london_weekends     london
# 770          28.021241   4.90917  52.37256  amsterdam_weekdays  amsterdam
# 46538        29.236088  12.50171  41.89909       rome_weekends       rome
# 6786          2.838624  23.71993  37.96521     athens_weekends     athens
# 30888         5.781661  -0.24239  51.51745     london_weekends     london
# 26535         4.209174  -0.12795  51.41744     london_weekdays     london
# 13127        16.300592  19.03031  47.51166   budapest_weekdays   budapest
# 29608        11.683387  -0.06895  51.50192     london_weekends     london
# 42879        19.900666  12.51314  41.89491       rome_weekdays       rome
#
#        weekday
# 16483        1
# 31489        1
# 770          0
# 46538        1
# 6786         1
# 30888        1
# 26535        0
# 13127        0
# 29608        1
# 42879        0
#
# [10 rows x 23 columns]

# %%
# combining column room shared & room private
def get_room_type(row):
    if row['room_shared'] == 1:
        return 'shared'
    elif row['room_private'] == 1:
        return 'private'
    else:
        return 'entire_home'
    
dataset['room_type'] = dataset.apply(get_room_type, axis=1)
dataset["room_type"].unique()
# Out:
# array(['private', 'entire_home', 'shared'], dtype=object)

# %%
# removing the room_shared , room_private columns 
dataset = dataset.drop(["room_shared", "room_private"], axis=1)
dataset.sample(10)
# Out:
#        index       Price    room_type  person_capacity  host_is_superhost  \
# 7378      18  143.731887      private                2              False
# 12501   1102   97.283962      private                2              False
# 29563   2487  193.325337      private                2              False
# 44360    725  262.782596  entire_home                4              False
# 4007    1927  463.759286  entire_home                3              False
# 16104   1353  199.276214  entire_home                4               True
# 10313    469  214.117811      private                2              False
# 29013   1937  534.584539  entire_home                2              False
# 37411   1826  324.354553  entire_home                2              False
# 1726     623  319.640053      private                2               True
#
#        multi  biz  cleanliness_rating  guest_satisfaction_overall  bedrooms  \
# 7378       0    0                   9                          91         1
# 12501      0    0                   9                          95         1
# 29563      0    0                  10                         100         1
# 44360      0    0                   9                          90         2
# 4007       0    1                  10                         100         1
# 16104      1    0                  10                          97         1
# 10313      0    0                   9                          89         1
# 29013      0    1                  10                         100         1
# 37411      1    0                   7                          90         1
# 1726       0    0                  10                          96         1
#
#        ...  metro_dist  attr_index  attr_index_norm   rest_index  \
# 7378   ...    0.235625  171.955305        26.209530   187.260342
# 12501  ...    0.802124  156.312997         6.035425   268.623574
# 29563  ...    5.315506  124.898247         8.682164   255.329855
# 44360  ...    0.408167  908.254922        20.122790  1650.640544
# 4007   ...    0.288467  500.828296        18.883308   456.400644
# 16104  ...    0.076624  207.956014        12.411631   547.711786
# 10313  ...    0.232875  358.598887        12.221628   797.540139
# 29013  ...    0.217030  177.282485        12.323597   371.152955
# 37411  ...    0.264645  380.553177        18.504426  1013.827274
# 1726   ...    0.763698  139.739476         7.398565   183.439495
#
#        rest_index_norm       lng       lat          sheet_name       city  \
# 7378         39.618596  13.36538  52.49970     berlin_weekends     berlin
# 12501         5.900757   2.18524  41.43326  barcelona_weekends  barcelona
# 29563         4.569960  -0.04651  51.44124     london_weekends     london
# 44360        35.963453  12.48885  41.89592       rome_weekends       rome
# 4007         34.269338  23.72624  37.97357     athens_weekdays     athens
# 16104        47.879842  19.06094  47.48924   budapest_weekends   budapest
# 10313        17.556313   2.16156  41.37286  barcelona_weekdays  barcelona
# 29013         6.642991   0.00630  51.50155     london_weekends     london
# 37411        46.770216   2.35743  48.87018      paris_weekends      paris
# 1726         15.991521   4.84509  52.35752  amsterdam_weekends  amsterdam
#
#       weekday
# 7378        1
# 12501       1
# 29563       1
# 44360       1
# 4007        0
# 16104       1
# 10313       0
# 29013       1
# 37411       1
# 1726        1
#
# [10 rows x 21 columns]

# %%
# Instead of dummy variables, create a column where one can know if the host of the listing has only one, two to four, or more than four listings
dataset['host_listings_category'] = dataset['multi'].apply(
    lambda x: 'one' if x == 1 else ('two_to_four' if x <= 4 else 'more_than_four')
)
dataset.head(10)
# Out:
#    index        Price    room_type  person_capacity  host_is_superhost  multi  \
# 0      0   194.033698      private                2              False      1
# 1      1   344.245776      private                4              False      0
# 2      2   264.101422      private                2              False      0
# 3      3   433.529398      private                4              False      0
# 4      4   485.552926      private                2               True      0
# 5      5   552.808567      private                3              False      0
# 6      6   215.124317      private                2              False      0
# 7      7  2771.307384  entire_home                4               True      0
# 8      8  1001.804420  entire_home                4              False      0
# 9      9   276.521454      private                2              False      1
#
#    biz  cleanliness_rating  guest_satisfaction_overall  bedrooms  ...  \
# 0    0                  10                          93         1  ...
# 1    0                   8                          85         1  ...
# 2    1                   9                          87         1  ...
# 3    1                   9                          90         2  ...
# 4    0                  10                          98         1  ...
# 5    0                   8                         100         2  ...
# 6    0                  10                          94         1  ...
# 7    0                  10                         100         3  ...
# 8    0                   9                          96         2  ...
# 9    0                  10                          88         1  ...
#
#    attr_index  attr_index_norm  rest_index  rest_index_norm      lng  \
# 0   78.690379         4.166708   98.253896         6.846473  4.90569
# 1  631.176378        33.421209  837.280757        58.342928  4.90005
# 2   75.275877         3.985908   95.386955         6.646700  4.97512
# 3  493.272534        26.119108  875.033098        60.973565  4.89417
# 4  552.830324        29.272733  815.305740        56.811677  4.90051
# 5  174.788957         9.255191  225.201662        15.692376  4.87699
# 6  200.167652        10.599010  242.765524        16.916251  4.91570
# 7  208.808109        11.056528  272.313823        18.975219  4.88467
# 8  106.226456         5.624761  133.876202         9.328686  4.86459
# 9  206.252862        10.921226  238.291258        16.604478  4.87600
#
#         lat          sheet_name       city weekday host_listings_category
# 0  52.41772  amsterdam_weekdays  amsterdam       0                    one
# 1  52.37432  amsterdam_weekdays  amsterdam       0            two_to_four
# 2  52.36103  amsterdam_weekdays  amsterdam       0            two_to_four
# 3  52.37663  amsterdam_weekdays  amsterdam       0            two_to_four
# 4  52.37508  amsterdam_weekdays  amsterdam       0            two_to_four
# 5  52.38966  amsterdam_weekdays  amsterdam       0            two_to_four
# 6  52.38296  amsterdam_weekdays  amsterdam       0            two_to_four
# 7  52.38749  amsterdam_weekdays  amsterdam       0            two_to_four
# 8  52.40175  amsterdam_weekdays  amsterdam       0            two_to_four
# 9  52.34700  amsterdam_weekdays  amsterdam       0                    one
#
# [10 rows x 22 columns]

# %% [markdown]
# ### Some basic initial inspections
# <div style="
#     border: 2px solid orange;
#     border-radius: 8px;
#     padding: 0px;
#     margin: 10px 0;
#     background-color: inherit;
#     color: inherit;
# ">
# </div>

# %%
# displaying first row
dataset.head(1)
# Out:
#    index       Price room_type  person_capacity  host_is_superhost  multi  \
# 0      0  194.033698   private                2              False      1
#
#    biz  cleanliness_rating  guest_satisfaction_overall  bedrooms  ...  \
# 0    0                  10                          93         1  ...
#
#    attr_index  attr_index_norm  rest_index  rest_index_norm      lng  \
# 0   78.690379         4.166708   98.253896         6.846473  4.90569
#
#         lat          sheet_name       city weekday host_listings_category
# 0  52.41772  amsterdam_weekdays  amsterdam       0                    one
#
# [1 rows x 22 columns]

# %%
# last row
dataset.tail(1)
# Out:
#        index       Price room_type  person_capacity  host_is_superhost  multi  \
# 51706   1798  133.230489   private                4               True      1
#
#        biz  cleanliness_rating  guest_satisfaction_overall  bedrooms  ...  \
# 51706    0                  10                          93         1  ...
#
#        attr_index  attr_index_norm  rest_index  rest_index_norm       lng  \
# 51706  150.450381        10.774264  225.247293          5.44414  16.39066
#
#             lat       sheet_name    city weekday host_listings_category
# 51706  48.20811  vienna_weekends  vienna       1                    one
#
# [1 rows x 22 columns]

# %%
# random seven samples
dataset.sample(7)
# Out:
#        index       Price    room_type  person_capacity  host_is_superhost  \
# 5362     629   81.081714  entire_home                3              False
# 34551   2096  242.566875  entire_home                2               True
# 10089    245  202.480974      private                2               True
# 21631   2075  308.864916  entire_home                6              False
# 3857    1777  134.745624  entire_home                4              False
# 22109   2553  253.283302  entire_home                4               True
# 33867   1412  318.762233  entire_home                2              False
#
#        multi  biz  cleanliness_rating  guest_satisfaction_overall  bedrooms  \
# 5362       0    0                  10                          97         1
# 34551      0    0                  10                          97         1
# 10089      0    0                  10                          95         1
# 21631      0    1                   9                          91         2
# 3857       0    1                  10                         100         1
# 22109      0    1                  10                         100         1
# 33867      0    1                   9                          76         1
#
#        ...  attr_index  attr_index_norm  rest_index  rest_index_norm  \
# 5362   ...   61.557109         2.319333   90.792380         1.355888
# 34551  ...  201.984719         9.832548  545.241326        32.038128
# 10089  ...  286.744618         9.772719  639.620659        14.080019
# 21631  ...  139.958082         4.616275  437.172881        24.570272
# 3857   ...  101.521642         3.827788  140.433321        10.544588
# 22109  ...  252.995606         8.344622  560.188644        31.484083
# 33867  ...  302.167891        14.709431  815.825639        47.937537
#
#             lng       lat          sheet_name       city weekday  \
# 5362   23.72508  38.00006     athens_weekends     athens       1
# 34551   2.39450  48.85010      paris_weekdays      paris       0
# 10089   2.14441  41.39794  barcelona_weekdays  barcelona       0
# 21631  -9.15779  38.70928     lisbon_weekends     lisbon       1
# 3857   23.75072  37.97991     athens_weekdays     athens       0
# 22109  -9.13140  38.71813     lisbon_weekends     lisbon       1
# 33867   2.37000  48.87000      paris_weekdays      paris       0
#
#       host_listings_category
# 5362             two_to_four
# 34551            two_to_four
# 10089            two_to_four
# 21631            two_to_four
# 3857             two_to_four
# 22109            two_to_four
# 33867            two_to_four
#
# [7 rows x 22 columns]

# %%
# checking data types
dataset.dtypes
# Out:
# index                           int64
# Price                         float64
# room_type                      object
# person_capacity                 int64
# host_is_superhost                bool
# multi                           int64
# biz                             int64
# cleanliness_rating              int64
# guest_satisfaction_overall      int64
# bedrooms                        int64
# dist                          float64
# metro_dist                    float64
# attr_index                    float64
# attr_index_norm               float64
# rest_index                    float64
# rest_index_norm               float64
# lng                           float64
# lat                           float64
# sheet_name                     object
# city                           object
# weekday                         int64
# host_listings_category         object
# dtype: object

# %%
# display numeric summery
dataset.describe()
# Out:
#               index         Price  person_capacity         multi  \
# count  51707.000000  51707.000000     51707.000000  51707.000000
# mean    1620.502388    279.879591         3.161661      0.291353
# std     1217.380366    327.948386         1.298545      0.454390
# min        0.000000     34.779339         2.000000      0.000000
# 25%      646.000000    148.752174         2.000000      0.000000
# 50%     1334.000000    211.343089         3.000000      0.000000
# 75%     2382.000000    319.694287         4.000000      1.000000
# max     5378.000000  18545.450285         6.000000      1.000000
#
#                 biz  cleanliness_rating  guest_satisfaction_overall  \
# count  51707.000000        51707.000000                51707.000000
# mean       0.350204            9.390624                   92.628232
# std        0.477038            0.954868                    8.945531
# min        0.000000            2.000000                   20.000000
# 25%        0.000000            9.000000                   90.000000
# 50%        0.000000           10.000000                   95.000000
# 75%        1.000000           10.000000                   99.000000
# max        1.000000           10.000000                  100.000000
#
#           bedrooms          dist    metro_dist    attr_index  attr_index_norm  \
# count  51707.00000  51707.000000  51707.000000  51707.000000     51707.000000
# mean       1.15876      3.191285      0.681540    294.204105        13.423792
# std        0.62741      2.393803      0.858023    224.754123         9.807985
# min        0.00000      0.015045      0.002301     15.152201         0.926301
# 25%        1.00000      1.453142      0.248480    136.797385         6.380926
# 50%        1.00000      2.613538      0.413269    234.331748        11.468305
# 75%        1.00000      4.263077      0.737840    385.756381        17.415082
# max       10.00000     25.284557     14.273577   4513.563486       100.000000
#
#          rest_index  rest_index_norm           lng           lat       weekday
# count  51707.000000     51707.000000  51707.000000  51707.000000  51707.000000
# mean     626.856696        22.786177      7.426068     45.671128      0.506837
# std      497.920226        17.804096      9.799725      5.249263      0.499958
# min       19.576924         0.592757     -9.226340     37.953000      0.000000
# 25%      250.854114         8.751480     -0.072500     41.399510      0.000000
# 50%      522.052783        17.542238      4.873000     47.506690      1.000000
# 75%      832.628988        32.964603     13.518825     51.471885      1.000000
# max     6696.156772       100.000000     23.786020     52.641410      1.000000

# %%
#getting statistics on categorical/object columns
obj_cols = dataset.select_dtypes(include='object').columns
print(f"This dataset has {len(obj_cols)} object columns:", list(obj_cols))
# Out:
# This dataset has 4 object columns: ['room_type', 'sheet_name', 'city', 'host_listings_category']

# %%
#detailed statistics on object data
for col in dataset.select_dtypes(include='object'):
    print(f"\nColumn: {col}")
    print("Count of non-null values:", dataset[col].count()) 
    print("Number of unique values:", dataset[col].nunique())
    print("Most frequent value:", dataset[col].value_counts().idxmax())
    print("Most frequent value (frequency):", dataset[col].value_counts().max())
    print("Least frequent value:", dataset[col].value_counts().idxmin())
    print("Least frequent value (frequency):", dataset[col].value_counts().min())
# Out:
# Column: room_type
# Count of non-null values: 51707
# Number of unique values: 3
# Most frequent value: entire_home
# Most frequent value (frequency): 32648
# Least frequent value: shared
# Least frequent value (frequency): 366
#
# Column: sheet_name
# Count of non-null values: 51707
# Number of unique values: 20
# Most frequent value: london_weekends
# Most frequent value (frequency): 5379
# Least frequent value: amsterdam_weekends
# Least frequent value (frequency): 977
#
# Column: city
# Count of non-null values: 51707
# Number of unique values: 10
# Most frequent value: london
# Most frequent value (frequency): 9993
# Least frequent value: amsterdam
# Least frequent value (frequency): 2080
#
# Column: host_listings_category
# Count of non-null values: 51707
# Number of unique values: 2
# Most frequent value: two_to_four
# Most frequent value (frequency): 36642
# Least frequent value: one
# Least frequent value (frequency): 15065
