# %%
# import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels.api as sm
from scipy.stats import chi2_contingency
from scipy.stats import shapiro, levene
from itertools import combinations
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import statsmodels as stats

# %%
# Import the data

# %%
# world bank dataset
world_bank = pd.read_csv(r"C:\Users\julia\Downloads\world_bank_development_indicators.csv")

# income dataset
income_data = pd.ExcelFile(r"C:\Users\julia\Downloads\income.xlsx")

# %%
 income_data.sheet_names
# Out:
# ['List of economies', 'composition', 'notes']

# %%
# only reading first sheet in excel file
economy_income = pd.read_excel(income_data, sheet_name='List of economies')
economy_income
# Out:
#                                         Economy Code  \
# 0                                   Afghanistan  AFG
# 1                                       Albania  ALB
# 2                                       Algeria  DZA
# 3                                American Samoa  ASM
# 4                                       Andorra  AND
# ..                                          ...  ...
# 262                          Sub-Saharan Africa  SSF
# 263  Sub-Saharan Africa (excluding high income)  SSA
# 264             Sub-Saharan Africa (IDA & IBRD)  TSS
# 265                         Upper middle income  UMC
# 266                                       World  WLD
#
#                                                 Region         Income group  \
# 0    Middle East, North Africa, Afghanistan & Pakistan           Low income
# 1                                Europe & Central Asia  Upper middle income
# 2    Middle East, North Africa, Afghanistan & Pakistan  Upper middle income
# 3                                  East Asia & Pacific          High income
# 4                                Europe & Central Asia          High income
# ..                                                 ...                  ...
# 262                                                NaN                  NaN
# 263                                                NaN                  NaN
# 264                                                NaN                  NaN
# 265                                                NaN                  NaN
# 266                                                NaN                  NaN
#
#     Lending category
# 0                IDA
# 1               IBRD
# 2               IBRD
# 3                NaN
# 4                NaN
# ..               ...
# 262              NaN
# 263              NaN
# 264              NaN
# 265              NaN
# 266              NaN
#
# [267 rows x 5 columns]

# %%
# Add income/region information by merging the tables into a single dataframe.

world_bank = world_bank.merge(economy_income[['Economy', 'Income group', 'Region']], 
                       how='left', 
                       left_on='country', 
                       right_on='Economy').drop(columns=['Economy'])

# %%
world_bank.sample(10)
# Out:
#                 country        date  agricultural_land%  forest_land%  \
# 14110           Somalia  1963-01-01           70.001913           NaN
# 17033             World  1977-01-01           37.289663           NaN
# 14118           Somalia  1971-01-01           70.065674           NaN
# 11033           Myanmar  2022-01-01                 NaN           NaN
# 3195   Congo, Dem. Rep.  2019-01-01           14.922476     56.133129
# 5883          Gibraltar  1990-01-01                 NaN      0.000000
# 4350   Egypt, Arab Rep.  1960-01-01                 NaN           NaN
# 792               Aruba  1984-01-01           11.111111           NaN
# 10111         Mauritius  1963-01-01           49.261084           NaN
# 15162            Sweden  1960-01-01                 NaN           NaN
#
#           land_area  avg_precipitation  trade_in_services%  \
# 14110  6.273400e+05              282.0                 NaN
# 17033  1.076968e+08                NaN            6.766930
# 14118  6.273400e+05              282.0                 NaN
# 11033           NaN                NaN                 NaN
# 3195   2.267050e+06             1543.0            4.639101
# 5883   1.000000e+01                NaN                 NaN
# 4350            NaN                NaN                 NaN
# 792    1.800000e+02                NaN                 NaN
# 10111  2.030000e+03             2041.0                 NaN
# 15162           NaN                NaN                 NaN
#
#        control_of_corruption_estimate  control_of_corruption_std  \
# 14110                             NaN                        NaN
# 17033                             NaN                        NaN
# 14118                             NaN                        NaN
# 11033                       -1.151623                   0.165523
# 3195                        -1.555178                   0.151915
# 5883                              NaN                        NaN
# 4350                              NaN                        NaN
# 792                               NaN                        NaN
# 10111                             NaN                        NaN
# 15162                             NaN                        NaN
#
#        access_to_electricity%  ...  birth_rate  death_rate  \
# 14110                     NaN  ...   45.968000   20.539000
# 17033                     NaN  ...   27.892856   10.787706
# 14118                     NaN  ...   45.198000   19.185000
# 11033                     NaN  ...         NaN         NaN
# 3195                     19.1  ...   42.656000    9.380000
# 5883                    100.0  ...   17.226000    7.359000
# 4350                      NaN  ...   47.405000   21.364000
# 792                       NaN  ...   21.183000    6.366000
# 10111                     NaN  ...   40.400000    9.700000
# 15162                     NaN  ...   13.700000   10.000000
#
#        life_expectancy_at_birth    population  rural_population  \
# 14110                 44.100000  3.102170e+06      2.515239e+06
# 17033                 61.120867  4.215826e+09      2.605496e+09
# 14118                 45.747000  3.818389e+06      2.930575e+06
# 11033                       NaN  5.417931e+07      3.696600e+07
# 3195                  60.276000  8.990689e+07      4.940743e+07
# 5883                  77.072000  2.731700e+04      0.000000e+00
# 4350                  45.373000  2.703450e+07      1.679816e+07
# 792                   72.251000  6.417400e+04      3.182300e+04
# 10111                 58.353220  7.188610e+05      4.508260e+05
# 15162                 73.005610  7.484656e+06      2.059029e+06
#
#        voice_and_accountability_estimate  voice_and_accountability_std  \
# 14110                                NaN                           NaN
# 17033                                NaN                           NaN
# 14118                                NaN                           NaN
# 11033                          -1.809050                      0.128449
# 3195                           -1.314188                      0.122940
# 5883                                 NaN                           NaN
# 4350                                 NaN                           NaN
# 792                                  NaN                           NaN
# 10111                                NaN                           NaN
# 15162                                NaN                           NaN
#
#        intentional_homicides         Income group  \
# 14110                    NaN                  NaN
# 17033                    NaN                  NaN
# 14118                    NaN                  NaN
# 11033                    NaN  Lower middle income
# 3195                     NaN           Low income
# 5883                     NaN          High income
# 4350                     NaN  Lower middle income
# 792                      NaN          High income
# 10111                    NaN  Upper middle income
# 15162                    NaN          High income
#
#                                                   Region
# 14110                                                NaN
# 17033                                                NaN
# 14118                                                NaN
# 11033                                East Asia & Pacific
# 3195                                  Sub-Saharan Africa
# 5883                               Europe & Central Asia
# 4350   Middle East, North Africa, Afghanistan & Pakistan
# 792                            Latin America & Caribbean
# 10111                                 Sub-Saharan Africa
# 15162                              Europe & Central Asia
#
# [10 rows x 52 columns]

# %%
world_bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17272 entries, 0 to 17271
# Data columns (total 52 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   country                                    17272 non-null  object
#  1   date                                       17272 non-null  object
#  2   agricultural_land%                         14714 non-null  float64
#  3   forest_land%                               8176 non-null   float64
#  4   land_area                                  14930 non-null  float64
#  5   avg_precipitation                          10086 non-null  float64
#  6   trade_in_services%                         9195 non-null   float64
#  7   control_of_corruption_estimate             4783 non-null   float64
#  8   control_of_corruption_std                  4783 non-null   float64
#  9   access_to_electricity%                     7348 non-null   float64
#  10  renewvable_energy_consumption%             8076 non-null   float64
#  11  electric_power_consumption                 7790 non-null   float64
#  12  CO2_emisions                               7408 non-null   float64
#  13  other_greenhouse_emisions                  7408 non-null   float64
#  14  population_density                         14901 non-null  float64
#  15  inflation_annual%                          10788 non-null  float64
#  16  real_interest_rate                         4416 non-null   float64
#  17  risk_premium_on_lending                    2370 non-null   float64
#  18  research_and_development_expenditure%      2889 non-null   float64
#  19  central_goverment_debt%                    2080 non-null   float64
#  20  tax_revenue%                               5125 non-null   float64
#  21  expense%                                   4769 non-null   float64
#  22  goverment_effectiveness_estimate           4759 non-null   float64
#  23  goverment_effectiveness_std                4759 non-null   float64
#  24  human_capital_index                        601 non-null    float64
#  25  doing_business                             189 non-null    float64
#  26  time_to_get_operation_license              371 non-null    float64
#  27  statistical_performance_indicators         1237 non-null   float64
#  28  individuals_using_internet%                8044 non-null   float64
#  29  logistic_performance_index                 1407 non-null   float64
#  30  military_expenditure%                      10122 non-null  float64
#  31  GDP_current_US                             13198 non-null  float64
#  32  political_stability_estimate               4820 non-null   float64
#  33  political_stability_std                    4820 non-null   float64
#  34  rule_of_law_estimate                       4873 non-null   float64
#  35  rule_of_law_std                            4873 non-null   float64
#  36  regulatory_quality_estimate                4761 non-null   float64
#  37  regulatory_quality_std                     4761 non-null   float64
#  38  government_expenditure_on_education%       6107 non-null   float64
#  39  government_health_expenditure%             4938 non-null   float64
#  40  multidimensional_poverty_headcount_ratio%  455 non-null    float64
#  41  gini_index                                 2108 non-null   float64
#  42  birth_rate                                 16037 non-null  float64
#  43  death_rate                                 16019 non-null  float64
#  44  life_expectancy_at_birth                   15866 non-null  float64
#  45  population                                 16665 non-null  float64
#  46  rural_population                           16539 non-null  float64
#  47  voice_and_accountability_estimate          4850 non-null   float64
#  48  voice_and_accountability_std               4850 non-null   float64
#  49  intentional_homicides                      4209 non-null   float64
#  50  Income group                               13343 non-null  object
#  51  Region                                     13471 non-null  object
# dtypes: float64(48), object(4)
# memory usage: 6.9+ MB

# %%
# dataset column name notaions struture
world_bank.columns = (
    world_bank.columns
    .str.lower()
    .str.strip()
    .str.replace(" ", "_")
    .str.replace(r"[^a-z0-9_]", "", regex=True)
)
world_bank.head()
# Out:
#        country        date  agricultural_land  forest_land  land_area  \
# 0  Afghanistan  1960-01-01                NaN          NaN        NaN
# 1  Afghanistan  1961-01-01          57.878356          NaN   652230.0
# 2  Afghanistan  1962-01-01          57.955016          NaN   652230.0
# 3  Afghanistan  1963-01-01          58.031676          NaN   652230.0
# 4  Afghanistan  1964-01-01          58.116002          NaN   652230.0
#
#    avg_precipitation  trade_in_services  control_of_corruption_estimate  \
# 0                NaN                NaN                             NaN
# 1              327.0                NaN                             NaN
# 2              327.0                NaN                             NaN
# 3              327.0                NaN                             NaN
# 4              327.0                NaN                             NaN
#
#    control_of_corruption_std  access_to_electricity  ...  birth_rate  \
# 0                        NaN                    NaN  ...      50.340
# 1                        NaN                    NaN  ...      50.443
# 2                        NaN                    NaN  ...      50.570
# 3                        NaN                    NaN  ...      50.703
# 4                        NaN                    NaN  ...      50.831
#
#    death_rate  life_expectancy_at_birth  population  rural_population  \
# 0      31.921                    32.535   8622466.0         7898093.0
# 1      31.349                    33.068   8790140.0         8026804.0
# 2      30.845                    33.547   8969047.0         8163985.0
# 3      30.359                    34.016   9157465.0         8308019.0
# 4      29.867                    34.494   9355514.0         8458694.0
#
#    voice_and_accountability_estimate  voice_and_accountability_std  \
# 0                                NaN                           NaN
# 1                                NaN                           NaN
# 2                                NaN                           NaN
# 3                                NaN                           NaN
# 4                                NaN                           NaN
#
#    intentional_homicides  income_group  \
# 0                    NaN    Low income
# 1                    NaN    Low income
# 2                    NaN    Low income
# 3                    NaN    Low income
# 4                    NaN    Low income
#
#                                               region
# 0  Middle East, North Africa, Afghanistan & Pakistan
# 1  Middle East, North Africa, Afghanistan & Pakistan
# 2  Middle East, North Africa, Afghanistan & Pakistan
# 3  Middle East, North Africa, Afghanistan & Pakistan
# 4  Middle East, North Africa, Afghanistan & Pakistan
#
# [5 rows x 52 columns]

# %%
# Clean up countries

# %%
world_bank['country'].unique()
# Out:
# array(['Afghanistan', 'Africa Eastern and Southern',
#        'Africa Western and Central', 'Albania', 'Algeria',
#        'American Samoa', 'Andorra', 'Angola', 'Antigua and Barbuda',
#        'Arab World', 'Argentina', 'Armenia', 'Aruba', 'Australia',
#        'Austria', 'Azerbaijan', 'Bahamas, The', 'Bahrain', 'Bangladesh',
#        'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda',
#        'Bhutan', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana',
#        'Brazil', 'British Virgin Islands', 'Brunei Darussalam',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia',
#        'Cameroon', 'Canada', 'Caribbean small states', 'Cayman Islands',
#        'Central African Republic', 'Central Europe and the Baltics',
#        'Chad', 'Channel Islands', 'Chile', 'China', 'Colombia', 'Comoros',
#        'Congo, Dem. Rep.', 'Congo, Rep.', 'Costa Rica', "Cote d'Ivoire",
#        'Croatia', 'Cuba', 'Curacao', 'Cyprus', 'Czech Republic',
#        'Czechia', 'Denmark', 'Djibouti', 'Dominica', 'Dominican Republic',
#        'Early-demographic dividend', 'East Asia & Pacific',
#        'East Asia & Pacific (IDA & IBRD countries)',
#        'East Asia & Pacific (IDA & IBRD)',
#        'East Asia & Pacific (excluding high income)', 'Ecuador',
#        'Egypt, Arab Rep.', 'El Salvador', 'Equatorial Guinea', 'Eritrea',
#        'Estonia', 'Eswatini', 'Ethiopia', 'Euro area',
#        'Europe & Central Asia',
#        'Europe & Central Asia (IDA & IBRD countries)',
#        'Europe & Central Asia (IDA & IBRD)',
#        'Europe & Central Asia (excluding high income)', 'European Union',
#        'Faroe Islands', 'Fiji', 'Finland',
#        'Fragile and conflict affected situations', 'France',
#        'French Polynesia', 'Gabon', 'Gambia, The', 'Georgia', 'Germany',
#        'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada', 'Guam',
#        'Guatemala', 'Guinea', 'Guinea-Bissau', 'Guyana', 'Haiti',
#        'Heavily indebted poor countries (HIPC)', 'High income',
#        'Honduras', 'Hong Kong SAR, China', 'Hungary', 'IBRD only',
#        'IDA & IBRD total', 'IDA blend', 'IDA only', 'IDA total',
#        'Iceland', 'India', 'Indonesia', 'Iran, Islamic Rep.', 'Iraq',
#        'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan',
#        'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati',
#        "Korea, Dem. People's Rep.", 'Korea, Rep.', 'Kosovo', 'Kuwait',
#        'Kyrgyz Republic', 'Lao PDR', 'Late-demographic dividend',
#        'Latin America & Caribbean',
#        'Latin America & Caribbean (IDA & IBRD)',
#        'Latin America & Caribbean (excluding high income)',
#        'Latin America & the Caribbean (IDA & IBRD countries)', 'Latvia',
#        'Least developed countries: UN classification', 'Lebanon',
#        'Lesotho', 'Liberia', 'Libya', 'Liechtenstein', 'Lithuania',
#        'Low & middle income', 'Low income', 'Lower middle income',
#        'Luxembourg', 'Macao SAR, China', 'Madagascar', 'Malawi',
#        'Malaysia', 'Maldives', 'Mali', 'Malta', 'Marshall Islands',
#        'Mauritania', 'Mauritius', 'Mexico', 'Micronesia, Fed. Sts.',
#        'Middle East & North Africa',
#        'Middle East & North Africa (IDA & IBRD countries)',
#        'Middle East & North Africa (IDA & IBRD)',
#        'Middle East & North Africa (excluding high income)',
#        'Middle income', 'Moldova', 'Monaco', 'Mongolia', 'Montenegro',
#        'Morocco', 'Mozambique', 'Myanmar', 'Namibia', 'Nauru', 'Nepal',
#        'Netherlands', 'New Caledonia', 'New Zealand', 'Nicaragua',
#        'Niger', 'Nigeria', 'North America', 'North Macedonia',
#        'Northern Mariana Islands', 'Norway', 'Not classified',
#        'OECD members', 'Oman', 'Other small states',
#        'Pacific island small states', 'Pakistan', 'Palau', 'Panama',
#        'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Poland',
#        'Portugal', 'Post-demographic dividend',
#        'Pre-demographic dividend', 'Puerto Rico', 'Qatar', 'Romania',
#        'Russian Federation', 'Rwanda', 'Samoa', 'San Marino',
#        'Sao Tome and Principe', 'Saudi Arabia', 'Senegal', 'Serbia',
#        'Seychelles', 'Sierra Leone', 'Singapore',
#        'Sint Maarten (Dutch part)', 'Slovak Republic', 'Slovenia',
#        'Small states', 'Solomon Islands', 'Somalia', 'South Africa',
#        'South Asia', 'South Asia (IDA & IBRD)', 'South Sudan', 'Spain',
#        'Sri Lanka', 'St. Kitts and Nevis', 'St. Lucia',
#        'St. Martin (French part)', 'St. Vincent and the Grenadines',
#        'Sub-Saharan Africa', 'Sub-Saharan Africa (IDA & IBRD countries)',
#        'Sub-Saharan Africa (IDA & IBRD)',
#        'Sub-Saharan Africa (excluding high income)', 'Sudan', 'Suriname',
#        'Sweden', 'Switzerland', 'Syrian Arab Republic', 'Tajikistan',
#        'Tanzania', 'Thailand', 'Timor-Leste', 'Togo', 'Tonga',
#        'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkiye',
#        'Turkmenistan', 'Turks and Caicos Islands', 'Tuvalu', 'Uganda',
#        'Ukraine', 'United Arab Emirates', 'United Kingdom',
#        'United States', 'Upper middle income', 'Uruguay', 'Uzbekistan',
#        'Vanuatu', 'Venezuela, RB', 'Viet Nam', 'Vietnam',
#        'Virgin Islands (U.S.)', 'West Bank and Gaza', 'World',
#        'Yemen, Rep.', 'Zambia', 'Zimbabwe'], dtype=object)

# %%
# removing empty rows from income_grop
world_bank = world_bank.dropna(subset=['income_group'])
world_bank.shape
# Out:
# (13343, 52)

# %%
# unique values in life life_expectancy_at_birth
world_bank['life_expectancy_at_birth'].unique()
# Out:
# array([32.535, 33.068, 33.547, ..., 61.414, 61.124, 59.253],
#       shape=(11082,))

# %%
# checking null values
world_bank['life_expectancy_at_birth'].isnull().sum()
# Out:
# np.int64(1006)

# %%
# droping nan values from life_expectancy_at_birth
world_bank = world_bank.dropna(subset=['life_expectancy_at_birth'])
world_bank.shape
# Out:
# (12337, 52)

# %%
# checking duplicates
world_bank.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Some basic initial inspections

# %%
# display the first, the last and a random sample of 7 entries
world_bank.head(1), world_bank.tail(1), world_bank.sample(7)
# Out:
# (       country        date  agricultural_land  forest_land  land_area  \
#  0  Afghanistan  1960-01-01                NaN          NaN        NaN
#
#     avg_precipitation  trade_in_services  control_of_corruption_estimate  \
#  0                NaN                NaN                             NaN
#
#     control_of_corruption_std  access_to_electricity  ...  birth_rate  \
#  0                        NaN                    NaN  ...       50.34
#
#     death_rate  life_expectancy_at_birth  population  rural_population  \
#  0      31.921                    32.535   8622466.0         7898093.0
#
#     voice_and_accountability_estimate  voice_and_accountability_std  \
#  0                                NaN                           NaN
#
#     intentional_homicides  income_group  \
#  0                    NaN    Low income
#
#                                                region
#  0  Middle East, North Africa, Afghanistan & Pakistan
#
#  [1 rows x 52 columns],
#          country        date  agricultural_land  forest_land  land_area  \
#  17269  Zimbabwe  2021-01-01          41.876696    44.974822   386850.0
#
#         avg_precipitation  trade_in_services  control_of_corruption_estimate  \
#  17269                NaN                NaN                        -1.25355
#
#         control_of_corruption_std  access_to_electricity  ...  birth_rate  \
#  17269                   0.151591              48.979927  ...      30.537
#
#         death_rate  life_expectancy_at_birth  population  rural_population  \
#  17269       9.057                    59.253  15993524.0        10827136.0
#
#         voice_and_accountability_estimate  voice_and_accountability_std  \
#  17269                           -1.13583                        0.1203
#
#         intentional_homicides         income_group              region
#  17269               6.139985  Lower middle income  Sub-Saharan Africa
#
#  [1 rows x 52 columns],
#                       country        date  agricultural_land  forest_land  \
#  3065                Colombia  2017-01-01          39.195133    53.843867
#  11425              Nicaragua  1966-01-01          29.749044          NaN
#  10265  Micronesia, Fed. Sts.  1989-01-01                NaN          NaN
#  8310                  Kuwait  1985-01-01           7.687991          NaN
#  3734                 Czechia  2015-01-01          45.253206    34.560161
#  15295   Syrian Arab Republic  1965-01-01          77.804984          NaN
#  10205                 Mexico  1993-01-01          54.620746    35.972407
#
#         land_area  avg_precipitation  trade_in_services  \
#  3065   1109500.0             3240.0           7.550977
#  11425   120340.0             2280.0                NaN
#  10265        NaN                NaN                NaN
#  8310     17820.0              121.0          24.356795
#  3734     77210.0              677.0          22.886063
#  15295   183780.0              252.0                NaN
#  10205  1943950.0              758.0           5.088079
#
#         control_of_corruption_estimate  control_of_corruption_std  \
#  3065                        -0.429445                   0.123802
#  11425                             NaN                        NaN
#  10265                             NaN                        NaN
#  8310                              NaN                        NaN
#  3734                         0.468282                   0.118750
#  15295                             NaN                        NaN
#  10205                             NaN                        NaN
#
#         access_to_electricity  ...  birth_rate  death_rate  \
#  3065               98.500000  ...      15.081       5.249
#  11425                    NaN  ...      47.799      14.914
#  10265                    NaN  ...      34.694       5.925
#  8310                     NaN  ...      30.717       2.458
#  3734              100.000000  ...      10.500      10.500
#  15295                    NaN  ...      46.348      13.081
#  10205              95.448463  ...      28.144       5.489
#
#         life_expectancy_at_birth  population  rural_population  \
#  3065                  76.646000  48351671.0         9454686.0
#  11425                 51.316000   2150003.0         1213354.0
#  10265                 67.096000     96796.0           71741.0
#  8310                  73.074000   1888975.0           39612.0
#  3734                  78.578049  10546059.0         2797131.0
#  15295                 57.113000   5368451.0         3220748.0
#  10205                 70.942000  86648447.0        23743407.0
#
#         voice_and_accountability_estimate  voice_and_accountability_std  \
#  3065                            0.112487                      0.125744
#  11425                                NaN                           NaN
#  10265                                NaN                           NaN
#  8310                                 NaN                           NaN
#  3734                            1.042779                      0.129967
#  15295                                NaN                           NaN
#  10205                                NaN                           NaN
#
#         intentional_homicides         income_group  \
#  3065               25.434488  Upper middle income
#  11425                    NaN  Lower middle income
#  10265                    NaN  Lower middle income
#  8310                     NaN          High income
#  3734                0.836200          High income
#  15295                    NaN           Low income
#  10205              18.511584  Upper middle income
#
#                                                    region
#  3065                           Latin America & Caribbean
#  11425                          Latin America & Caribbean
#  10265                                East Asia & Pacific
#  8310   Middle East, North Africa, Afghanistan & Pakistan
#  3734                               Europe & Central Asia
#  15295  Middle East, North Africa, Afghanistan & Pakistan
#  10205                          Latin America & Caribbean
#
#  [7 rows x 52 columns])

# %%
# check data types
world_bank.dtypes
# Out:
# country                                      object
# date                                         object
# agricultural_land                           float64
# forest_land                                 float64
# land_area                                   float64
# avg_precipitation                           float64
# trade_in_services                           float64
# control_of_corruption_estimate              float64
# control_of_corruption_std                   float64
# access_to_electricity                       float64
# renewvable_energy_consumption               float64
# electric_power_consumption                  float64
# co2_emisions                                float64
# other_greenhouse_emisions                   float64
# population_density                          float64
# inflation_annual                            float64
# real_interest_rate                          float64
# risk_premium_on_lending                     float64
# research_and_development_expenditure        float64
# central_goverment_debt                      float64
# tax_revenue                                 float64
# expense                                     float64
# goverment_effectiveness_estimate            float64
# goverment_effectiveness_std                 float64
# human_capital_index                         float64
# doing_business                              float64
# time_to_get_operation_license               float64
# statistical_performance_indicators          float64
# individuals_using_internet                  float64
# logistic_performance_index                  float64
# military_expenditure                        float64
# gdp_current_us                              float64
# political_stability_estimate                float64
# political_stability_std                     float64
# rule_of_law_estimate                        float64
# rule_of_law_std                             float64
# regulatory_quality_estimate                 float64
# regulatory_quality_std                      float64
# government_expenditure_on_education         float64
# government_health_expenditure               float64
# multidimensional_poverty_headcount_ratio    float64
# gini_index                                  float64
# birth_rate                                  float64
# death_rate                                  float64
# life_expectancy_at_birth                    float64
# population                                  float64
# rural_population                            float64
# voice_and_accountability_estimate           float64
# voice_and_accountability_std                float64
# intentional_homicides                       float64
# income_group                                 object
# region                                       object
# dtype: object

# %%
# check missing values
world_bank.isna().sum()
# Out:
# country                                         0
# date                                            0
# agricultural_land                            1465
# forest_land                                  6166
# land_area                                    1321
# avg_precipitation                            2750
# trade_in_services                            5668
# control_of_corruption_estimate               8034
# control_of_corruption_std                    8034
# access_to_electricity                        6661
# renewvable_energy_consumption                6190
# electric_power_consumption                   6709
# co2_emisions                                 6696
# other_greenhouse_emisions                    6696
# population_density                           1321
# inflation_annual                             4244
# real_interest_rate                           8164
# risk_premium_on_lending                     10056
# research_and_development_expenditure        10158
# central_goverment_debt                      10571
# tax_revenue                                  8195
# expense                                      8385
# goverment_effectiveness_estimate             8058
# goverment_effectiveness_std                  8058
# human_capital_index                         11757
# doing_business                              12158
# time_to_get_operation_license               12035
# statistical_performance_indicators          11329
# individuals_using_internet                   6260
# logistic_performance_index                  11443
# military_expenditure                         5211
# gdp_current_us                               2729
# political_stability_estimate                 8025
# political_stability_std                      8025
# rule_of_law_estimate                         7981
# rule_of_law_std                              7981
# regulatory_quality_estimate                  8056
# regulatory_quality_std                       8056
# government_expenditure_on_education          7731
# government_health_expenditure                8615
# multidimensional_poverty_headcount_ratio    11904
# gini_index                                  10305
# birth_rate                                     22
# death_rate                                     17
# life_expectancy_at_birth                        0
# population                                      0
# rural_population                              124
# voice_and_accountability_estimate            7999
# voice_and_accountability_std                 7999
# intentional_homicides                        8576
# income_group                                    0
# region                                          0
# dtype: int64

# %%
# checking duplicates values
world_bank.duplicated().sum()
# Out:
# np.int64(0)

# %%
# basic summary statistics for both categorical
#getting statistics on categorical/object columns
obj_cols = world_bank.select_dtypes(include='object').columns
print(f"This dataset has {len(obj_cols)} object columns:", list(obj_cols))
# Out:
# This dataset has 4 object columns: ['country', 'date', 'income_group', 'region']

# %%
#detailed statistics on object data
for col in world_bank.select_dtypes(include='object'):
    print(f"\nColumn: {col}")
    print("Count of non-null values:", world_bank[col].count()) 
    print("Number of unique values:", world_bank[col].nunique())
    print("Most frequent value:", world_bank[col].value_counts().idxmax())
    print("Most frequent value (frequency):", world_bank[col].value_counts().max())
    print("Least frequent value:", world_bank[col].value_counts().idxmin())
    print("Least frequent value (frequency):", world_bank[col].value_counts().min())
# Out:
# Column: country
# Count of non-null values: 12337
# Number of unique values: 203
# Most frequent value: Afghanistan
# Most frequent value (frequency): 62
# Least frequent value: Cayman Islands
# Least frequent value (frequency): 1
#
# Column: date
# Count of non-null values: 12337
# Number of unique values: 62
# Most frequent value: 2000-01-01
# Most frequent value (frequency): 202
# Least frequent value: 1965-01-01
# Least frequent value (frequency): 195
#
# Column: income_group
# Count of non-null values: 12337
# Number of unique values: 4
# Most frequent value: High income
# Most frequent value (frequency): 4679
# Least frequent value: Low income
# Least frequent value (frequency): 1488
#
# Column: region
# Count of non-null values: 12337
# Number of unique values: 7
# Most frequent value: Europe & Central Asia
# Most frequent value (frequency): 3272
# Least frequent value: North America
# Least frequent value (frequency): 186

# %%
# numerical variables
world_bank.describe()
# Out:
#        agricultural_land  forest_land     land_area  avg_precipitation  \
# count       10872.000000  6171.000000  1.101600e+04        9587.000000
# mean           36.859765    32.024224  6.333164e+05        1197.780640
# std            22.429526    24.656054  1.700936e+06         801.397558
# min             0.262821     0.000000  1.000000e+01          18.100000
# 25%            17.769203    10.882353  1.487000e+04         589.000000
# 50%            37.647385    30.270000  1.074000e+05        1083.000000
# 75%            54.710446    50.851685  4.727100e+05        1732.000000
# max            93.440750    98.574551  1.638995e+07        3240.000000
#
#        trade_in_services  control_of_corruption_estimate  \
# count        6669.000000                     4303.000000
# mean           23.638020                       -0.022664
# std            25.049107                        1.002276
# min             0.621025                       -1.936706
# 25%             9.821090                       -0.799936
# 50%            16.197962                       -0.257588
# 75%            27.779357                        0.666760
# max           327.166162                        2.459118
#
#        control_of_corruption_std  access_to_electricity  \
# count                4303.000000            5676.000000
# mean                    0.199437              80.971078
# std                     0.080858              29.641385
# min                     0.114062               0.533899
# 25%                     0.147376              70.463633
# 50%                     0.172068              99.093647
# 75%                     0.221240             100.000000
# max                     0.942502             100.000000
#
#        renewvable_energy_consumption  electric_power_consumption  ...  \
# count                    6147.000000                 5628.000000  ...
# mean                       30.652775                 3253.943467  ...
# std                        30.384863                 4510.362635  ...
# min                         0.000000                    5.548906  ...
# 25%                         3.725000                  442.235588  ...
# 50%                        19.780000                 1637.804168  ...
# 75%                        53.015000                 4399.794384  ...
# max                        98.340000                54799.174708  ...
#
#        multidimensional_poverty_headcount_ratio   gini_index    birth_rate  \
# count                                433.000000  2032.000000  12315.000000
# mean                                  26.855810    37.704429     27.899943
# std                                   10.706123     8.897723     13.043383
# min                                    2.370000    20.700000      5.000000
# 25%                                   18.500000    31.100000     16.000000
# 50%                                   24.800000    35.500000     26.467000
# 75%                                   32.600000    43.000000     39.642000
# max                                   74.200000    65.800000     58.121000
#
#          death_rate  life_expectancy_at_birth    population  rural_population  \
# count  12320.000000              12337.000000  1.233700e+04      1.221300e+04
# mean      10.359263                 64.841867  2.575121e+07      1.405247e+07
# std        5.546529                 11.264059  1.077548e+08      7.130716e+07
# min        0.795000                 11.995000  2.646000e+03      0.000000e+00
# 25%        6.800000                 57.947000  6.636530e+05      2.973540e+05
# 50%        9.070500                 67.661780  4.440300e+06      1.973563e+06
# 75%       12.243000                 73.080000  1.348335e+07      7.284867e+06
# max      103.534000                 85.497561  1.412360e+09      9.093848e+08
#
#        voice_and_accountability_estimate  voice_and_accountability_std  \
# count                        4338.000000                   4338.000000
# mean                           -0.024143                      0.164513
# std                             0.991458                      0.059423
# min                            -2.313395                      0.103012
# 25%                            -0.828785                      0.126784
# 50%                             0.008879                      0.142200
# 75%                             0.855610                      0.189655
# max                             1.800992                      0.578548
#
#        intentional_homicides
# count            3761.000000
# mean                7.858061
# std                12.187223
# min                 0.000000
# 25%                 1.273807
# 50%                 3.056778
# 75%                 9.010965
# max               138.773986
#
# [8 rows x 48 columns]

# %%
# correlation
world_bank.corr(numeric_only=True)
# Out:
#                                           agricultural_land  forest_land  \
# agricultural_land                                  1.000000    -0.458758
# forest_land                                       -0.458758     1.000000
# land_area                                          0.001600    -0.002582
# avg_precipitation                                 -0.297814     0.659278
# trade_in_services                                 -0.187452    -0.035680
# control_of_corruption_estimate                    -0.209995     0.028293
# control_of_corruption_std                         -0.216473     0.075231
# access_to_electricity                             -0.133978    -0.080257
# renewvable_energy_consumption                      0.080677     0.223300
# electric_power_consumption                        -0.263808    -0.084089
# co2_emisions                                       0.064763    -0.025484
# other_greenhouse_emisions                          0.071427    -0.029675
# population_density                                -0.106656    -0.146297
# inflation_annual                                  -0.010238     0.032969
# real_interest_rate                                 0.024585     0.004705
# risk_premium_on_lending                            0.106111     0.027847
# research_and_development_expenditure              -0.199715     0.196585
# central_goverment_debt                             0.014379    -0.016599
# tax_revenue                                        0.042615    -0.059327
# expense                                            0.063711    -0.155362
# goverment_effectiveness_estimate                  -0.208939     0.026769
# goverment_effectiveness_std                       -0.245705     0.091222
# human_capital_index                               -0.230283     0.061048
# doing_business                                    -0.012131     0.049087
# time_to_get_operation_license                      0.054206    -0.061679
# statistical_performance_indicators                 0.081276    -0.023597
# individuals_using_internet                        -0.123854    -0.021837
# logistic_performance_index                        -0.132845     0.005336
# military_expenditure                              -0.077640    -0.205958
# gdp_current_us                                     0.045637     0.018122
# political_stability_estimate                      -0.231232     0.170016
# political_stability_std                           -0.074961     0.035317
# rule_of_law_estimate                              -0.194384     0.019921
# rule_of_law_std                                   -0.186520     0.082892
# regulatory_quality_estimate                       -0.147646     0.005301
# regulatory_quality_std                            -0.215020     0.046292
# government_expenditure_on_education                0.010289    -0.018467
# government_health_expenditure                      0.018879    -0.024958
# multidimensional_poverty_headcount_ratio           0.220813     0.027267
# gini_index                                        -0.079463     0.290046
# birth_rate                                        -0.030196     0.022660
# death_rate                                         0.119528     0.089553
# life_expectancy_at_birth                          -0.046757    -0.068246
# population                                         0.114777    -0.037719
# rural_population                                   0.110529    -0.051540
# voice_and_accountability_estimate                 -0.133629     0.173784
# voice_and_accountability_std                      -0.196474     0.078603
# intentional_homicides                              0.004053     0.213048
#
#                                           land_area  avg_precipitation  \
# agricultural_land                          0.001600          -0.297814
# forest_land                               -0.002582           0.659278
# land_area                                  1.000000          -0.171256
# avg_precipitation                         -0.171256           1.000000
# trade_in_services                         -0.215777           0.099198
# control_of_corruption_estimate            -0.020428           0.005827
# control_of_corruption_std                 -0.165377           0.196425
# access_to_electricity                      0.048991          -0.089262
# renewvable_energy_consumption             -0.045525           0.264676
# electric_power_consumption                 0.123749          -0.131218
# co2_emisions                               0.593403          -0.099825
# other_greenhouse_emisions                  0.632393          -0.100069
# population_density                        -0.067301           0.131237
# inflation_annual                           0.034759           0.001156
# real_interest_rate                        -0.006045           0.044908
# risk_premium_on_lending                    0.044927           0.052100
# research_and_development_expenditure       0.118664          -0.077546
# central_goverment_debt                    -0.047090           0.004488
# tax_revenue                               -0.148969          -0.084141
# expense                                   -0.123131          -0.315907
# goverment_effectiveness_estimate           0.033265           0.008099
# goverment_effectiveness_std               -0.147398           0.209240
# human_capital_index                        0.106410          -0.074756
# doing_business                            -0.141639           0.133625
# time_to_get_operation_license              0.120266          -0.044802
# statistical_performance_indicators         0.133639          -0.086134
# individuals_using_internet                 0.045410          -0.068607
# logistic_performance_index                 0.121132          -0.083899
# military_expenditure                       0.021825          -0.256408
# gdp_current_us                             0.406244          -0.068159
# political_stability_estimate              -0.113240           0.100600
# political_stability_std                   -0.102408           0.089366
# rule_of_law_estimate                      -0.022612          -0.006718
# rule_of_law_std                           -0.134878           0.205424
# regulatory_quality_estimate                0.018036          -0.003520
# regulatory_quality_std                    -0.112760           0.104102
# government_expenditure_on_education       -0.008028          -0.127516
# government_health_expenditure              0.054232          -0.100202
# multidimensional_poverty_headcount_ratio   0.093548          -0.016288
# gini_index                                 0.116132           0.455183
# birth_rate                                -0.061581           0.042636
# death_rate                                 0.003962          -0.064898
# life_expectancy_at_birth                   0.020022          -0.028366
# population                                 0.487176          -0.047990
# rural_population                           0.399269          -0.034405
# voice_and_accountability_estimate         -0.049622           0.153404
# voice_and_accountability_std              -0.118469           0.167353
# intentional_homicides                      0.055874           0.293777
#
#                                           trade_in_services  \
# agricultural_land                                 -0.187452
# forest_land                                       -0.035680
# land_area                                         -0.215777
# avg_precipitation                                  0.099198
# trade_in_services                                  1.000000
# control_of_corruption_estimate                     0.310761
# control_of_corruption_std                          0.245798
# access_to_electricity                              0.190644
# renewvable_energy_consumption                     -0.269485
# electric_power_consumption                         0.181370
# co2_emisions                                      -0.129860
# other_greenhouse_emisions                         -0.144853
# population_density                                 0.260190
# inflation_annual                                  -0.031672
# real_interest_rate                                -0.004547
# risk_premium_on_lending                           -0.081316
# research_and_development_expenditure               0.036564
# central_goverment_debt                             0.173135
# tax_revenue                                        0.299334
# expense                                            0.209393
# goverment_effectiveness_estimate                   0.287127
# goverment_effectiveness_std                        0.316215
# human_capital_index                                0.274584
# doing_business                                    -0.124233
# time_to_get_operation_license                      0.061007
# statistical_performance_indicators                 0.083148
# individuals_using_internet                         0.221648
# logistic_performance_index                         0.226439
# military_expenditure                              -0.028824
# gdp_current_us                                    -0.107746
# political_stability_estimate                       0.353569
# political_stability_std                            0.083757
# rule_of_law_estimate                               0.323948
# rule_of_law_std                                    0.240321
# regulatory_quality_estimate                        0.278187
# regulatory_quality_std                             0.263499
# government_expenditure_on_education                0.103675
# government_health_expenditure                      0.186983
# multidimensional_poverty_headcount_ratio          -0.183899
# gini_index                                        -0.201748
# birth_rate                                        -0.199778
# death_rate                                        -0.168794
# life_expectancy_at_birth                           0.238526
# population                                        -0.154641
# rural_population                                  -0.130459
# voice_and_accountability_estimate                  0.276768
# voice_and_accountability_std                       0.271775
# intentional_homicides                             -0.081243
#
#                                           control_of_corruption_estimate  \
# agricultural_land                                              -0.209995
# forest_land                                                     0.028293
# land_area                                                      -0.020428
# avg_precipitation                                               0.005827
# trade_in_services                                               0.310761
# control_of_corruption_estimate                                  1.000000
# control_of_corruption_std                                       0.082057
# access_to_electricity                                           0.476000
# renewvable_energy_consumption                                  -0.371562
# electric_power_consumption                                      0.655920
# co2_emisions                                                    0.073458
# other_greenhouse_emisions                                       0.057767
# population_density                                              0.144324
# inflation_annual                                               -0.072177
# real_interest_rate                                             -0.063301
# risk_premium_on_lending                                        -0.228477
# research_and_development_expenditure                            0.683586
# central_goverment_debt                                          0.247987
# tax_revenue                                                     0.373729
# expense                                                         0.347991
# goverment_effectiveness_estimate                                0.920593
# goverment_effectiveness_std                                     0.141277
# human_capital_index                                             0.742867
# doing_business                                                 -0.681433
# time_to_get_operation_license                                   0.214613
# statistical_performance_indicators                              0.561858
# individuals_using_internet                                      0.592377
# logistic_performance_index                                      0.792874
# military_expenditure                                           -0.012576
# gdp_current_us                                                  0.190438
# political_stability_estimate                                    0.747631
# political_stability_std                                        -0.013558
# rule_of_law_estimate                                            0.938691
# rule_of_law_std                                                 0.105725
# regulatory_quality_estimate                                     0.863453
# regulatory_quality_std                                          0.215610
# government_expenditure_on_education                             0.352273
# government_health_expenditure                                   0.634726
# multidimensional_poverty_headcount_ratio                       -0.687146
# gini_index                                                     -0.382237
# birth_rate                                                     -0.597499
# death_rate                                                     -0.120580
# life_expectancy_at_birth                                        0.634413
# population                                                     -0.062522
# rural_population                                               -0.094646
# voice_and_accountability_estimate                               0.768894
# voice_and_accountability_std                                    0.217395
# intentional_homicides                                          -0.210301
#
#                                           control_of_corruption_std  \
# agricultural_land                                         -0.216473
# forest_land                                                0.075231
# land_area                                                 -0.165377
# avg_precipitation                                          0.196425
# trade_in_services                                          0.245798
# control_of_corruption_estimate                             0.082057
# control_of_corruption_std                                  1.000000
# access_to_electricity                                     -0.055077
# renewvable_energy_consumption                             -0.063791
# electric_power_consumption                                -0.047255
# co2_emisions                                              -0.126377
# other_greenhouse_emisions                                 -0.137317
# population_density                                         0.078366
# inflation_annual                                           0.025963
# real_interest_rate                                         0.049553
# risk_premium_on_lending                                   -0.052144
# research_and_development_expenditure                      -0.185902
# central_goverment_debt                                    -0.023710
# tax_revenue                                                0.070937
# expense                                                    0.088960
# goverment_effectiveness_estimate                          -0.020282
# goverment_effectiveness_std                                0.726645
# human_capital_index                                       -0.142719
# doing_business                                             0.261407
# time_to_get_operation_license                             -0.153429
# statistical_performance_indicators                        -0.393698
# individuals_using_internet                                -0.250231
# logistic_performance_index                                -0.312078
# military_expenditure                                       0.140183
# gdp_current_us                                            -0.141579
# political_stability_estimate                               0.222569
# political_stability_std                                    0.765302
# rule_of_law_estimate                                       0.085396
# rule_of_law_std                                            0.902436
# regulatory_quality_estimate                               -0.067165
# regulatory_quality_std                                     0.808671
# government_expenditure_on_education                        0.037571
# government_health_expenditure                             -0.005904
# multidimensional_poverty_headcount_ratio                  -0.002941
# gini_index                                                 0.160347
# birth_rate                                                 0.154964
# death_rate                                                -0.040442
# life_expectancy_at_birth                                  -0.149225
# population                                                -0.148568
# rural_population                                          -0.119533
# voice_and_accountability_estimate                          0.080121
# voice_and_accountability_std                               0.787512
# intentional_homicides                                      0.131347
#
#                                           access_to_electricity  \
# agricultural_land                                     -0.133978
# forest_land                                           -0.080257
# land_area                                              0.048991
# avg_precipitation                                     -0.089262
# trade_in_services                                      0.190644
# control_of_corruption_estimate                         0.476000
# control_of_corruption_std                             -0.055077
# access_to_electricity                                  1.000000
# renewvable_energy_consumption                         -0.782931
# electric_power_consumption                             0.414108
# co2_emisions                                           0.134179
# other_greenhouse_emisions                              0.131367
# population_density                                     0.103609
# inflation_annual                                       0.008285
# real_interest_rate                                    -0.072363
# risk_premium_on_lending                               -0.183296
# research_and_development_expenditure                   0.267567
# central_goverment_debt                                 0.079328
# tax_revenue                                            0.159468
# expense                                                0.328341
# goverment_effectiveness_estimate                       0.579798
# goverment_effectiveness_std                            0.190081
# human_capital_index                                    0.727923
# doing_business                                        -0.569918
# time_to_get_operation_license                          0.207551
# statistical_performance_indicators                     0.481191
# individuals_using_internet                             0.465018
# logistic_performance_index                             0.518582
# military_expenditure                                   0.049496
# gdp_current_us                                         0.136443
# political_stability_estimate                           0.406992
# political_stability_std                               -0.140334
# rule_of_law_estimate                                   0.511588
# rule_of_law_std                                        0.015749
# regulatory_quality_estimate                            0.529407
# regulatory_quality_std                                 0.163841
# government_expenditure_on_education                    0.183242
# government_health_expenditure                          0.470375
# multidimensional_poverty_headcount_ratio              -0.413151
# gini_index                                            -0.326280
# birth_rate                                            -0.829276
# death_rate                                            -0.408610
# life_expectancy_at_birth                               0.832060
# population                                             0.021407
# rural_population                                      -0.027474
# voice_and_accountability_estimate                      0.395380
# voice_and_accountability_std                           0.084363
# intentional_homicides                                 -0.073030
#
#                                           renewvable_energy_consumption  \
# agricultural_land                                              0.080677
# forest_land                                                    0.223300
# land_area                                                     -0.045525
# avg_precipitation                                              0.264676
# trade_in_services                                             -0.269485
# control_of_corruption_estimate                                -0.371562
# control_of_corruption_std                                     -0.063791
# access_to_electricity                                         -0.782931
# renewvable_energy_consumption                                  1.000000
# electric_power_consumption                                    -0.264196
# co2_emisions                                                  -0.140406
# other_greenhouse_emisions                                     -0.132879
# population_density                                            -0.140625
# inflation_annual                                               0.038143
# real_interest_rate                                             0.086294
# risk_premium_on_lending                                        0.242382
# research_and_development_expenditure                          -0.155967
# central_goverment_debt                                         0.039258
# tax_revenue                                                   -0.212611
# expense                                                       -0.313741
# goverment_effectiveness_estimate                              -0.458865
# goverment_effectiveness_std                                   -0.245624
# human_capital_index                                           -0.559052
# doing_business                                                 0.370230
# time_to_get_operation_license                                 -0.130473
# statistical_performance_indicators                            -0.206741
# individuals_using_internet                                    -0.320772
# logistic_performance_index                                    -0.435579
# military_expenditure                                          -0.126673
# gdp_current_us                                                -0.133000
# political_stability_estimate                                  -0.356839
# political_stability_std                                        0.027200
# rule_of_law_estimate                                          -0.414508
# rule_of_law_std                                               -0.130853
# regulatory_quality_estimate                                   -0.404696
# regulatory_quality_std                                        -0.196400
# government_expenditure_on_education                           -0.180185
# government_health_expenditure                                 -0.372963
# multidimensional_poverty_headcount_ratio                       0.066159
# gini_index                                                     0.315903
# birth_rate                                                     0.669641
# death_rate                                                     0.438080
# life_expectancy_at_birth                                      -0.676926
# population                                                     0.003455
# rural_population                                               0.045177
# voice_and_accountability_estimate                             -0.280414
# voice_and_accountability_std                                  -0.184734
# intentional_homicides                                          0.074574
#
#                                           electric_power_consumption  ...  \
# agricultural_land                                          -0.263808  ...
# forest_land                                                -0.084089  ...
# land_area                                                   0.123749  ...
# avg_precipitation                                          -0.131218  ...
# trade_in_services                                           0.181370  ...
# control_of_corruption_estimate                              0.655920  ...
# control_of_corruption_std                                  -0.047255  ...
# access_to_electricity                                       0.414108  ...
# renewvable_energy_consumption                              -0.264196  ...
# electric_power_consumption                                  1.000000  ...
# co2_emisions                                                0.126220  ...
# other_greenhouse_emisions                                   0.108209  ...
# population_density                                          0.069373  ...
# inflation_annual                                           -0.034847  ...
# real_interest_rate                                         -0.035594  ...
# risk_premium_on_lending                                    -0.155318  ...
# research_and_development_expenditure                        0.575685  ...
# central_goverment_debt                                      0.019796  ...
# tax_revenue                                                 0.248107  ...
# expense                                                     0.276624  ...
# goverment_effectiveness_estimate                            0.636421  ...
# goverment_effectiveness_std                                 0.058672  ...
# human_capital_index                                         0.502430  ...
# doing_business                                                   NaN  ...
# time_to_get_operation_license                               0.095275  ...
# statistical_performance_indicators                          0.983109  ...
# individuals_using_internet                                  0.535193  ...
# logistic_performance_index                                  0.557832  ...
# military_expenditure                                       -0.017089  ...
# gdp_current_us                                              0.224425  ...
# political_stability_estimate                                0.512792  ...
# political_stability_std                                    -0.101789  ...
# rule_of_law_estimate                                        0.641146  ...
# rule_of_law_std                                            -0.010960  ...
# regulatory_quality_estimate                                 0.562248  ...
# regulatory_quality_std                                      0.089871  ...
# government_expenditure_on_education                         0.315098  ...
# government_health_expenditure                               0.490500  ...
# multidimensional_poverty_headcount_ratio                   -0.488156  ...
# gini_index                                                 -0.440925  ...
# birth_rate                                                 -0.494273  ...
# death_rate                                                 -0.212395  ...
# life_expectancy_at_birth                                    0.547881  ...
# population                                                 -0.063650  ...
# rural_population                                           -0.101133  ...
# voice_and_accountability_estimate                           0.435134  ...
# voice_and_accountability_std                                0.111487  ...
# intentional_homicides                                      -0.250662  ...
#
#                                           multidimensional_poverty_headcount_ratio  \
# agricultural_land                                                         0.220813
# forest_land                                                               0.027267
# land_area                                                                 0.093548
# avg_precipitation                                                        -0.016288
# trade_in_services                                                        -0.183899
# control_of_corruption_estimate                                           -0.687146
# control_of_corruption_std                                                -0.002941
# access_to_electricity                                                    -0.413151
# renewvable_energy_consumption                                             0.066159
# electric_power_consumption                                               -0.488156
# co2_emisions                                                             -0.122593
# other_greenhouse_emisions                                                -0.086464
# population_density                                                       -0.115437
# inflation_annual                                                          0.243485
# real_interest_rate                                                        0.210474
# risk_premium_on_lending                                                   0.364527
# research_and_development_expenditure                                     -0.604741
# central_goverment_debt                                                   -0.157347
# tax_revenue                                                              -0.315625
# expense                                                                  -0.210446
# goverment_effectiveness_estimate                                         -0.692423
# goverment_effectiveness_std                                              -0.055883
# human_capital_index                                                      -0.653966
# doing_business                                                            0.245257
# time_to_get_operation_license                                            -0.200348
# statistical_performance_indicators                                       -0.427447
# individuals_using_internet                                               -0.666289
# logistic_performance_index                                               -0.651403
# military_expenditure                                                      0.069415
# gdp_current_us                                                           -0.207992
# political_stability_estimate                                             -0.584896
# political_stability_std                                                   0.139471
# rule_of_law_estimate                                                     -0.707198
# rule_of_law_std                                                          -0.174369
# regulatory_quality_estimate                                              -0.624229
# regulatory_quality_std                                                   -0.406101
# government_expenditure_on_education                                      -0.435100
# government_health_expenditure                                            -0.581546
# multidimensional_poverty_headcount_ratio                                  1.000000
# gini_index                                                                0.512122
# birth_rate                                                                0.437071
# death_rate                                                                0.143948
# life_expectancy_at_birth                                                 -0.599168
# population                                                                0.104131
# rural_population                                                          0.191066
# voice_and_accountability_estimate                                        -0.638812
# voice_and_accountability_std                                             -0.192075
# intentional_homicides                                                     0.265382
#
#                                           gini_index  birth_rate  death_rate  \
# agricultural_land                          -0.079463   -0.030196    0.119528
# forest_land                                 0.290046    0.022660    0.089553
# land_area                                   0.116132   -0.061581    0.003962
# avg_precipitation                           0.455183    0.042636   -0.064898
# trade_in_services                          -0.201748   -0.199778   -0.168794
# control_of_corruption_estimate             -0.382237   -0.597499   -0.120580
# control_of_corruption_std                   0.160347    0.154964   -0.040442
# access_to_electricity                      -0.326280   -0.829276   -0.408610
# renewvable_energy_consumption               0.315903    0.669641    0.438080
# electric_power_consumption                 -0.440925   -0.494273   -0.212395
# co2_emisions                                0.012829   -0.172750   -0.030371
# other_greenhouse_emisions                   0.026413   -0.167522   -0.031902
# population_density                         -0.208379   -0.167592   -0.141682
# inflation_annual                            0.079767    0.027030    0.040077
# real_interest_rate                          0.284987    0.004984   -0.114426
# risk_premium_on_lending                     0.363794    0.165569   -0.047815
# research_and_development_expenditure       -0.367970   -0.404649    0.077788
# central_goverment_debt                     -0.099179   -0.021977    0.048387
# tax_revenue                                -0.382528   -0.295704    0.103192
# expense                                    -0.481368   -0.399236    0.197492
# goverment_effectiveness_estimate           -0.412223   -0.687152   -0.151927
# goverment_effectiveness_std                -0.138296   -0.105704   -0.130714
# human_capital_index                        -0.520127   -0.863124    0.079424
# doing_business                              0.456551    0.710118   -0.181396
# time_to_get_operation_license               0.181470   -0.191674   -0.036988
# statistical_performance_indicators         -0.368801   -0.605106    0.317306
# individuals_using_internet                 -0.459995   -0.574077   -0.163506
# logistic_performance_index                 -0.336634   -0.639020   -0.059419
# military_expenditure                        0.037414    0.131189   -0.066921
# gdp_current_us                             -0.008043   -0.198795   -0.052079
# political_stability_estimate               -0.348507   -0.522296   -0.089002
# political_stability_std                     0.173455    0.195834    0.084769
# rule_of_law_estimate                       -0.428694   -0.611249   -0.142007
# rule_of_law_std                             0.082265    0.094143   -0.065777
# regulatory_quality_estimate                -0.363710   -0.645429   -0.103726
# regulatory_quality_std                     -0.007512   -0.057174   -0.044402
# government_expenditure_on_education        -0.235578   -0.199073   -0.065186
# government_health_expenditure              -0.361364   -0.542228    0.046830
# multidimensional_poverty_headcount_ratio    0.512122    0.437071    0.143948
# gini_index                                  1.000000    0.480993   -0.295995
# birth_rate                                  0.480993    1.000000    0.539645
# death_rate                                 -0.295995    0.539645    1.000000
# life_expectancy_at_birth                   -0.385371   -0.870293   -0.803863
# population                                  0.025485   -0.074315   -0.043279
# rural_population                           -0.009823   -0.018285   -0.020952
# voice_and_accountability_estimate          -0.264510   -0.505180    0.025621
# voice_and_accountability_std                0.043463   -0.007257   -0.056153
# intentional_homicides                       0.570753    0.171471   -0.065755
#
#                                           life_expectancy_at_birth  \
# agricultural_land                                        -0.046757
# forest_land                                              -0.068246
# land_area                                                 0.020022
# avg_precipitation                                        -0.028366
# trade_in_services                                         0.238526
# control_of_corruption_estimate                            0.634413
# control_of_corruption_std                                -0.149225
# access_to_electricity                                     0.832060
# renewvable_energy_consumption                            -0.676926
# electric_power_consumption                                0.547881
# co2_emisions                                              0.144448
# other_greenhouse_emisions                                 0.136242
# population_density                                        0.175270
# inflation_annual                                         -0.044508
# real_interest_rate                                        0.035178
# risk_premium_on_lending                                  -0.118136
# research_and_development_expenditure                      0.537915
# central_goverment_debt                                    0.064496
# tax_revenue                                               0.250299
# expense                                                   0.331586
# goverment_effectiveness_estimate                          0.716366
# goverment_effectiveness_std                               0.100734
# human_capital_index                                       0.894246
# doing_business                                           -0.709071
# time_to_get_operation_license                             0.279976
# statistical_performance_indicators                        0.621227
# individuals_using_internet                                0.598855
# logistic_performance_index                                0.715031
# military_expenditure                                     -0.029607
# gdp_current_us                                            0.189916
# political_stability_estimate                              0.487866
# political_stability_std                                  -0.247087
# rule_of_law_estimate                                      0.659924
# rule_of_law_std                                          -0.085120
# regulatory_quality_estimate                               0.676183
# regulatory_quality_std                                    0.049196
# government_expenditure_on_education                       0.188496
# government_health_expenditure                             0.532685
# multidimensional_poverty_headcount_ratio                 -0.599168
# gini_index                                               -0.385371
# birth_rate                                               -0.870293
# death_rate                                               -0.803863
# life_expectancy_at_birth                                  1.000000
# population                                                0.028899
# rural_population                                         -0.024897
# voice_and_accountability_estimate                         0.508808
# voice_and_accountability_std                             -0.002760
# intentional_homicides                                    -0.236543
#
#                                           population  rural_population  \
# agricultural_land                           0.114777          0.110529
# forest_land                                -0.037719         -0.051540
# land_area                                   0.487176          0.399269
# avg_precipitation                          -0.047990         -0.034405
# trade_in_services                          -0.154641         -0.130459
# control_of_corruption_estimate             -0.062522         -0.094646
# control_of_corruption_std                  -0.148568         -0.119533
# access_to_electricity                       0.021407         -0.027474
# renewvable_energy_consumption               0.003455          0.045177
# electric_power_consumption                 -0.063650         -0.101133
# co2_emisions                                0.714221          0.552324
# other_greenhouse_emisions                   0.756131          0.600177
# population_density                         -0.019275         -0.015061
# inflation_annual                            0.000967         -0.000614
# real_interest_rate                         -0.017107         -0.019542
# risk_premium_on_lending                     0.017555         -0.019551
# research_and_development_expenditure        0.081637          0.011597
# central_goverment_debt                      0.002648         -0.015435
# tax_revenue                                -0.175707         -0.161467
# expense                                    -0.156188         -0.154157
# goverment_effectiveness_estimate            0.009310         -0.032782
# goverment_effectiveness_std                -0.121412         -0.107324
# human_capital_index                        -0.000886         -0.071385
# doing_business                             -0.110411         -0.058689
# time_to_get_operation_license              -0.007951         -0.048987
# statistical_performance_indicators          0.056914          0.015374
# individuals_using_internet                 -0.009794         -0.057929
# logistic_performance_index                  0.141540          0.077662
# military_expenditure                       -0.016300         -0.014742
# gdp_current_us                              0.384500          0.208099
# political_stability_estimate               -0.156713         -0.172920
# political_stability_std                    -0.096515         -0.068353
# rule_of_law_estimate                       -0.036989         -0.066206
# rule_of_law_std                            -0.105841         -0.085237
# regulatory_quality_estimate                -0.033360         -0.070311
# regulatory_quality_std                     -0.108270         -0.095917
# government_expenditure_on_education        -0.103680         -0.124769
# government_health_expenditure              -0.078025         -0.134479
# multidimensional_poverty_headcount_ratio    0.104131          0.191066
# gini_index                                  0.025485         -0.009823
# birth_rate                                 -0.074315         -0.018285
# death_rate                                 -0.043279         -0.020952
# life_expectancy_at_birth                    0.028899         -0.024897
# population                                  1.000000          0.968169
# rural_population                            0.968169          1.000000
# voice_and_accountability_estimate          -0.072593         -0.087202
# voice_and_accountability_std               -0.104696         -0.083563
# intentional_homicides                      -0.041075         -0.048120
#
#                                           voice_and_accountability_estimate  \
# agricultural_land                                                 -0.133629
# forest_land                                                        0.173784
# land_area                                                         -0.049622
# avg_precipitation                                                  0.153404
# trade_in_services                                                  0.276768
# control_of_corruption_estimate                                     0.768894
# control_of_corruption_std                                          0.080121
# access_to_electricity                                              0.395380
# renewvable_energy_consumption                                     -0.280414
# electric_power_consumption                                         0.435134
# co2_emisions                                                      -0.010904
# other_greenhouse_emisions                                         -0.020546
# population_density                                                 0.032102
# inflation_annual                                                  -0.078128
# real_interest_rate                                                 0.031565
# risk_premium_on_lending                                           -0.168442
# research_and_development_expenditure                               0.540684
# central_goverment_debt                                             0.219245
# tax_revenue                                                        0.436912
# expense                                                            0.467641
# goverment_effectiveness_estimate                                   0.755545
# goverment_effectiveness_std                                        0.146684
# human_capital_index                                                0.600157
# doing_business                                                    -0.479286
# time_to_get_operation_license                                      0.251235
# statistical_performance_indicators                                 0.532825
# individuals_using_internet                                         0.458341
# logistic_performance_index                                         0.653843
# military_expenditure                                              -0.290870
# gdp_current_us                                                     0.127246
# political_stability_estimate                                       0.670237
# political_stability_std                                            0.018762
# rule_of_law_estimate                                               0.817092
# rule_of_law_std                                                    0.146061
# regulatory_quality_estimate                                        0.779810
# regulatory_quality_std                                             0.171156
# government_expenditure_on_education                                0.329747
# government_health_expenditure                                      0.616732
# multidimensional_poverty_headcount_ratio                          -0.638812
# gini_index                                                        -0.264510
# birth_rate                                                        -0.505180
# death_rate                                                         0.025621
# life_expectancy_at_birth                                           0.508808
# population                                                        -0.072593
# rural_population                                                  -0.087202
# voice_and_accountability_estimate                                  1.000000
# voice_and_accountability_std                                       0.227010
# intentional_homicides                                             -0.010240
#
#                                           voice_and_accountability_std  \
# agricultural_land                                            -0.196474
# forest_land                                                   0.078603
# land_area                                                    -0.118469
# avg_precipitation                                             0.167353
# trade_in_services                                             0.271775
# control_of_corruption_estimate                                0.217395
# control_of_corruption_std                                     0.787512
# access_to_electricity                                         0.084363
# renewvable_energy_consumption                                -0.184734
# electric_power_consumption                                    0.111487
# co2_emisions                                                 -0.078510
# other_greenhouse_emisions                                    -0.088620
# population_density                                            0.208104
# inflation_annual                                              0.019743
# real_interest_rate                                            0.059306
# risk_premium_on_lending                                      -0.094995
# research_and_development_expenditure                         -0.041383
# central_goverment_debt                                       -0.021523
# tax_revenue                                                   0.122582
# expense                                                       0.086189
# goverment_effectiveness_estimate                              0.154660
# goverment_effectiveness_std                                   0.578030
# human_capital_index                                          -0.006883
# doing_business                                                0.179155
# time_to_get_operation_license                                -0.186213
# statistical_performance_indicators                           -0.372474
# individuals_using_internet                                   -0.186482
# logistic_performance_index                                    0.162078
# military_expenditure                                          0.104664
# gdp_current_us                                               -0.086255
# political_stability_estimate                                  0.302592
# political_stability_std                                       0.720161
# rule_of_law_estimate                                          0.232406
# rule_of_law_std                                               0.791486
# regulatory_quality_estimate                                   0.122449
# regulatory_quality_std                                        0.737242
# government_expenditure_on_education                           0.082195
# government_health_expenditure                                 0.148415
# multidimensional_poverty_headcount_ratio                     -0.192075
# gini_index                                                    0.043463
# birth_rate                                                   -0.007257
# death_rate                                                   -0.056153
# life_expectancy_at_birth                                     -0.002760
# population                                                   -0.104696
# rural_population                                             -0.083563
# voice_and_accountability_estimate                             0.227010
# voice_and_accountability_std                                  1.000000
# intentional_homicides                                         0.075153
#
#                                           intentional_homicides
# agricultural_land                                      0.004053
# forest_land                                            0.213048
# land_area                                              0.055874
# avg_precipitation                                      0.293777
# trade_in_services                                     -0.081243
# control_of_corruption_estimate                        -0.210301
# control_of_corruption_std                              0.131347
# access_to_electricity                                 -0.073030
# renewvable_energy_consumption                          0.074574
# electric_power_consumption                            -0.250662
# co2_emisions                                          -0.051495
# other_greenhouse_emisions                             -0.043721
# population_density                                    -0.082932
# inflation_annual                                       0.021281
# real_interest_rate                                     0.131668
# risk_premium_on_lending                                0.179738
# research_and_development_expenditure                  -0.309518
# central_goverment_debt                                -0.038071
# tax_revenue                                           -0.064719
# expense                                               -0.212558
# goverment_effectiveness_estimate                      -0.209321
# goverment_effectiveness_std                            0.110047
# human_capital_index                                   -0.365533
# doing_business                                         0.363701
# time_to_get_operation_license                          0.008410
# statistical_performance_indicators                    -0.304914
# individuals_using_internet                            -0.169974
# logistic_performance_index                            -0.243843
# military_expenditure                                  -0.142197
# gdp_current_us                                        -0.077676
# political_stability_estimate                          -0.145577
# political_stability_std                                0.059714
# rule_of_law_estimate                                  -0.270635
# rule_of_law_std                                        0.096364
# regulatory_quality_estimate                           -0.169898
# regulatory_quality_std                                 0.065645
# government_expenditure_on_education                   -0.042164
# government_health_expenditure                         -0.151006
# multidimensional_poverty_headcount_ratio               0.265382
# gini_index                                             0.570753
# birth_rate                                             0.171471
# death_rate                                            -0.065755
# life_expectancy_at_birth                              -0.236543
# population                                            -0.041075
# rural_population                                      -0.048120
# voice_and_accountability_estimate                     -0.010240
# voice_and_accountability_std                           0.075153
# intentional_homicides                                  1.000000
#
# [48 rows x 48 columns]

# %%
# chi square finding relations in object columns
# categorical_cols = ['country', 'date', 'income_group', 'region']


def chi_test(world_bank, col1, col2):
    table = pd.crosstab(world_bank[col1], world_bank[col2])
    chi2, p, dof, expected = chi2_contingency(table)
    print(f"{col1}  vs  {col2}  →  p-value = {p}")
    

# run chi-square for every pair => used obj_cols from basic summary statistics for both categorical from above code 
for col1, col2 in combinations(obj_cols, 2): 
    chi_test(world_bank, col1, col2)
# Out:
# country  vs  date  →  p-value = 1.0
# country  vs  income_group  →  p-value = 0.0
# country  vs  region  →  p-value = 0.0
# date  vs  income_group  →  p-value = 1.0
# date  vs  region  →  p-value = 1.0
# income_group  vs  region  →  p-value = 0.0

# %%
# basic plots for categorical and numerical variables to check distributions and counts (histogram, barplot)

# %%
# checking how many times each income_group appears.
plt.figure(figsize=(8,5))
sns.countplot(data=world_bank, x='income_group', order=world_bank['income_group'].value_counts().index)
plt.title("Income Group Distribution")
plt.show()

# %%
# region and income group => how income groups are distributed within each region.
ct = pd.crosstab(world_bank['region'], world_bank['income_group'])

ct.plot(kind='bar', stacked=True, figsize=(10,6), colormap='viridis')
plt.title("Stacked Bar: Region vs Income Group")
# x-axis => region
plt.xlabel("Region") 
# Y-axis => number of countries in that region.
plt.ylabel("Count")
plt.show()

# %%
# This grouped bar chart shows which region each country belongs to.
plt.figure(figsize=(12,6))
region_country = pd.crosstab(world_bank['country'], world_bank['region'])
region_country.plot(kind='bar', stacked=False, colormap='Set2', figsize=(25,10))
plt.title('Country vs Region (Grouped)')
plt.xlabel('Country')
plt.ylabel('Count')
plt.legend(title='Region')
plt.tight_layout()
plt.show()

# %%
# The heatmap highlights the distribution of income groups across regions.
plt.figure(figsize=(8,6))
income_region = pd.crosstab(world_bank['income_group'], world_bank['region'])
sns.heatmap(income_region, annot=True, fmt='d', cmap='YlGnBu')
plt.title('Income Group vs Region')
plt.xlabel('Region')
plt.ylabel('Income Group')
plt.tight_layout()
plt.show()

# %%
# Correlation heatmap (all variables) => Red indicates strong positive correlation, blue indicates strong negative correlation.
# The heatmap shows pairwise correlations between all numeric variables.
plt.figure(figsize=(15,12))
corr = world_bank.corr(numeric_only=True)
sns.heatmap(corr, cmap='coolwarm', center=0, linewidths=0.5)
plt.title('Correlation Heatmap')
plt.tight_layout()
plt.show()

# %%
# Scatter plot: Life Expectancy vs Access to Electricity => Countries with higher access to electricity tend to have higher life expectancy.
plt.figure(figsize=(8,6))
sns.scatterplot(data=world_bank, x='access_to_electricity', y='life_expectancy_at_birth', hue='income_group', palette='Set1')
plt.title('Life Expectancy vs Access to Electricity')
plt.xlabel('Access to Electricity (%)')
plt.ylabel('Life Expectancy at Birth (Years)')
plt.tight_layout()
plt.show()

# %%
# Scatter plot: Birth Rate vs Life Expectancy
# There is a clear negative correlation: countries with higher life expectancy have lower birth rates.
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x='life_expectancy_at_birth', y='birth_rate', hue='region', palette='Set2')
plt.title('Birth Rate vs Life Expectancy')
plt.xlabel('Life Expectancy at Birth (Years)')
plt.ylabel('Birth Rate (per 1000)')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[70], line 4
#       1 # Scatter plot: Birth Rate vs Life Expectancy
#       2 # There is a clear negative correlation: countries with higher life expectancy have lower birth rates.
#       3 plt.figure(figsize=(8,6))
# ----> 4 sns.scatterplot(data=df, x='life_expectancy_at_birth', y='birth_rate', hue='region', palette='Set2')
#       5 plt.title('Birth Rate vs Life Expectancy')
#       6 plt.xlabel('Life Expectancy at Birth (Years)')
#
# NameError: name 'df' is not defined

# %%
# Pairplot for selected key variables
selected_vars = ['life_expectancy_at_birth', 'birth_rate', 'access_to_electricity', 
                 'renewvable_energy_consumption', 'electric_power_consumption']
sns.pairplot(world_bank[selected_vars], kind='scatter', diag_kind='kde', corner=True)
plt.suptitle('Pairplot of Key Continuous Variables', y=1.02)
plt.show()

# The pairplot provides a compact view of relationships between several key variables.
# Diagonal plots show distributions; off-diagonal scatterplots show trends.
# For example, life expectancy vs birth rate is negative, while life expectancy vs electricity access is positive.

# %%
# ANOVA

# %%
# Boxplot – Visualizing Group Differences
plt.figure(figsize=(10, 6))
sns.boxplot(data=world_bank, x="income_group", y="life_expectancy_at_birth")
plt.title("Life Expectancy at Birth by Income Group")
plt.xlabel("Income Group")
plt.ylabel("Life Expectancy at Birth")
plt.xticks(rotation=45)
plt.show()

# %%
# Check assumptions for ANOVA
# Equal sample sizes of groups
groups_sizes_income = world_bank['income_group'].value_counts()
print("Groups Sizes:\n", groups_sizes_income)
# Out:
# Groups Sizes:
#  income_group
# High income            4679
# Upper middle income    3286
# Lower middle income    2884
# Low income             1488
# Name: count, dtype: int64

# %%
print("Normality test per group (Shapiro–Wilk):\n")
for group in world_bank["income_group"].unique():
    data = world_bank[world_bank["income_group"] == group]["life_expectancy_at_birth"]
    stat, p = shapiro(data)
    print(f"{group}: W={stat:.3f}, p={p:.3f}")
# Out:
# Normality test per group (Shapiro–Wilk):
#
# Low income: W=0.989, p=0.000
# Upper middle income: W=0.948, p=0.000
# Lower middle income: W=0.988, p=0.000
# High income: W=0.957, p=0.000

# %%
# Homogeneity of Variances (Levene test)
print("\nLevene Test for Homogeneity of Variances:")
stat, p = levene(*[world_bank[world_bank["income_group"] == group]["life_expectancy_at_birth"]
                   for group in world_bank["income_group"].unique()])
print(f"Levene stat={stat:.3f}, p={p:.3f}")
# Out:
# Levene Test for Homogeneity of Variances:
# Levene stat=336.239, p=0.000

# %%
# Run ANOVA
model = ols("life_expectancy_at_birth ~ C(income_group)", data=world_bank).fit()
anova_table = sm.stats.anova_lm(model, typ=2)   # typ=2 is fine even for unequal N
print("\nANOVA Table:")
print(anova_table)
# Out:
# ANOVA Table:
#                         sum_sq       df            F  PR(>F)
# C(income_group)  790690.028043      3.0  4196.991473     0.0
# Residual         774489.709111  12333.0          NaN     NaN

# %%
# Inspect Residuals
# Residual Plot
plt.figure(figsize=(8,5))
sns.histplot(model.resid, kde=True)
plt.title("Distribution of ANOVA Residuals")
plt.xlabel("Residuals")
plt.show()

# %%
# Q–Q plot of residuals
sm.qqplot(model.resid, line="s")
plt.title("Q–Q Plot of Residuals")
plt.show()

# %%
# Post-hoc Test (Tukey HSD)
tukey = pairwise_tukeyhsd(
    endog=world_bank["life_expectancy_at_birth"],
    groups=world_bank["income_group"],
    alpha=0.05
)

print("\nTukey HSD Post-Hoc Results:")
print(tukey)
# Out:
# Tukey HSD Post-Hoc Results:
#               Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================================================
#        group1              group2       meandiff p-adj  lower    upper   reject
# -------------------------------------------------------------------------------
#         High income          Low income   -22.96   0.0  -23.566  -22.354   True
#         High income Lower middle income -15.3906   0.0 -15.8726 -14.9086   True
#         High income Upper middle income   -7.259   0.0  -7.7225  -6.7956   True
#          Low income Lower middle income   7.5694   0.0   6.9195   8.2193   True
#          Low income Upper middle income   15.701   0.0  15.0648  16.3372   True
# Lower middle income Upper middle income   8.1316   0.0    7.612   8.6511   True
# -------------------------------------------------------------------------------

# %%
# Plot
tukey.plot_simultaneous(figsize=(10, 6))
plt.title("Tukey HSD – Pairwise Comparisons")
plt.show()

# %% [markdown]
# **Subsetting**

# %%
df_90_19 = world_bank[(world_bank["date"] <= "2019-01-01") & (world_bank["date"] >= "1990-01-01") ]
df = df_90_19[["country","date","agricultural_land","access_to_electricity","renewvable_energy_consumption","co2_emisions", "other_greenhouse_emisions", "population_density", "inflation_annual",
             "individuals_using_internet", "gdp_current_us", "birth_rate","death_rate","life_expectancy_at_birth", "population", "rural_population","income_group", "region"]]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6031 entries, 30 to 17267
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   country                        6031 non-null   object
#  1   date                           6031 non-null   object
#  2   agricultural_land              5757 non-null   float64
#  3   access_to_electricity          5276 non-null   float64
#  4   renewvable_energy_consumption  5886 non-null   float64
#  5   co2_emisions                   5459 non-null   float64
#  6   other_greenhouse_emisions      5459 non-null   float64
#  7   population_density             5835 non-null   float64
#  8   inflation_annual               4905 non-null   float64
#  9   individuals_using_internet     5600 non-null   float64
#  10  gdp_current_us                 5664 non-null   float64
#  11  birth_rate                     6028 non-null   float64
#  12  death_rate                     6028 non-null   float64
#  13  life_expectancy_at_birth       6031 non-null   float64
#  14  population                     6031 non-null   float64
#  15  rural_population               5971 non-null   float64
#  16  income_group                   6031 non-null   object
#  17  region                         6031 non-null   object
# dtypes: float64(14), object(4)
# memory usage: 895.2+ KB

# %%
df["income_group"].unique()
# Out:
# array(['Low income', 'Upper middle income', 'Lower middle income',
#        'High income'], dtype=object)

# %%
df["region"].unique()
# Out:
# array(['Middle East, North Africa, Afghanistan & Pakistan',
#        'Europe & Central Asia', 'Sub-Saharan Africa',
#        'Latin America & Caribbean', 'East Asia & Pacific', 'South Asia',
#        'North America'], dtype=object)

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
ordered_income = [
    "Low income",
    "Lower middle income",
    "Upper middle income",
    "High income"
]

income_group_ordered = pd.CategoricalDtype(
    categories=ordered_income,
    ordered=True
)

df["income_group"] = df["income_group"].astype(income_group_ordered)

# %%
df.to_csv ("week_05_group_4_cleaned_data.csv", index=False, encoding='utf-8')
# files.download("../additional_material/week_05_group_4_cleaned_data.csv")

# %% [markdown]
# **Birth rate vs. Income Group**

# %%
df = pd.read_csv("week_05_group_4_cleaned_data.csv")

# %%
df_br = df.dropna(subset=['birth_rate', 'income_group'])

# %%
df_br["log_birth_rate"] = np.log(df_br["birth_rate"]+1)

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

sns.histplot(x="birth_rate", data=df_br, bins=30, ax=axes[0])
axes[0].set_title('histogram of birth rate')

sns.histplot(x="log_birth_rate", data=df_br, bins=30, ax=axes[1])
axes[1].set_title('histogram of birth rate logarithm')

plt.tight_layout()
plt.show()

# %% [markdown]
# *   The bimodal distribution observed after the log transformation is most likely a result of the distinct, separate characteristics of your different income groups, where each group clusters around its own average birth rate.

# %%
#checking normal distribution and boxplot of co2
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

sns.histplot(x="birth_rate", data=df_br, bins=30, ax=axes[0])
axes[0].set_title('histogram of birth rate')

sns.boxplot(y="income_group", x="birth_rate", data=df_br, ax=axes[1])
axes[1].set_title('boxplot of birth rate')

plt.tight_layout()
plt.show()

# %%
formula = "log_birth_rate ~ C(income_group)" #it is recommended to put the formula in a variable called "formula"
model = ols(formula, data=df_br).fit()

# %%
aov_table = anova_lm(model, typ=2) #use tpy=2 for no interactions
aov_table
# Out:
#                      sum_sq      df            F  PR(>F)
# C(income_group)  863.242080     3.0  3173.475753     0.0
# Residual         546.211861  6024.0          NaN     NaN

# %% [markdown]
# Null Hypothesis:
#
# $$H_0: \mu_{\text{High}} = \mu_{\text{Low}} = \mu_{\text{Lower Middle}} = \mu_{\text{Upper Middle}}$$
#
# Which implies: There is no statistically significant difference in the mean of the dependent variable across the four income groups (High income, Low income, Lower middle income, and Upper middle income).
#
# The ANOVA test shows a highly significant difference in the mean of the dependent variable across the income groups, with an extremely large F-statistic of 3281.47 and a P-value of $0.0$ (rejecting the null hypothesis).

# %%
residuals = model.resid  #getting the residuals of the anova model

fig, axes = plt.subplots(1, 2, figsize=(14, 5))
sns.set_style("whitegrid")

# Residuals histogram
sns.histplot(model.resid, bins=30, kde=True, color='darkblue', ax=axes[0])
axes[0].set_title('Residuals Histogram')
axes[0].set_xlabel('Residuals')
axes[0].axvline(model.resid.mean(), color='black', linestyle='dashed', linewidth=1)

# Residuals vs. fitted values
axes[1].scatter(model.fittedvalues, model.resid, alpha=0.6, color='darkblue')
axes[1].axhline(0, color='red', linestyle='--', linewidth=1.5)
axes[1].set_xlabel("Fitted Values")
axes[1].set_ylabel("Residuals")
axes[1].set_title("Residuals vs Fitted Values")

plt.tight_layout()
plt.show()

# %% [markdown]
# * The plot of residuals against fitted values reveals four distinct vertical clusters, as expected for a model with a categorical predictor. However, the variance of the residuals appears non-constant across these clusters, suggesting a violation of the homoskedasticity assumption. This non-random pattern indicates that the model's standard errors and the validity of inference may be compromised, despite the residuals reportedly being normally distributed.

# %%
# Extracting the sum of squares values for the model and residuals
SS_model = aov_table['sum_sq'].iloc[:-1].sum()
SS_residual = aov_table['sum_sq'].iloc[-1]
# Total sum of squares
SS_total = SS_model + SS_residual

# Explained variance
explained_variance = SS_model / SS_total
print(f'Explained Variance: {explained_variance:.3f}')
# Out:
# Explained Variance: 0.612

# %% [markdown]
# * Based on the **ANOVA** results, the income groups account for $61.5\%$ of the total variance in the dependent variable ($R^2 = 0.615$), which, combined with the significant F-statistic (3281.47) and $P$-value ($0.0$), confirms that the groups are a powerful and statistically significant predictor in the model.

# %%
tukey = pairwise_tukeyhsd(endog=df_br['log_birth_rate'], groups=df_br['income_group'], alpha=0.05)
print(tukey)
# Out:
#              Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =============================================================================
#        group1              group2       meandiff p-adj  lower   upper  reject
# -----------------------------------------------------------------------------
#         High income          Low income   1.0336   0.0  1.0006  1.0667   True
#         High income Lower middle income   0.7788   0.0  0.7526   0.805   True
#         High income Upper middle income   0.3597   0.0  0.3345  0.3849   True
#          Low income Lower middle income  -0.2548   0.0 -0.2903 -0.2194   True
#          Low income Upper middle income  -0.6739   0.0 -0.7087 -0.6391   True
# Lower middle income Upper middle income  -0.4191   0.0 -0.4474 -0.3908   True
# -----------------------------------------------------------------------------

# %% [markdown]
# * **The Tukey HSD test** confirmed that the mean difference in $\mathbf{\text{Log}(\text{Birth Rate})}$ between every possible pair of income groups is statistically significant ($\mathbf{p < 0.05}$ for all pairs). This finding provides definitive quantitative support for the Demographic Transition Model, proving that each stage of economic development (income group) is associated with a unique and distinct average birth rate. The largest statistical difference was found between the two extremes, with Low income countries exhibiting a significantly higher mean birth rate than High income countries ($\text{meandiff} = 1.0368$).

# %% [markdown]
# **Average Carbon Intensity (CO2 / GDP) by Income Group**

# %%
df_co2 = df.dropna(subset=['gdp_current_us', 'co2_emisions'])
df_co2['carbon_intensity'] = df_co2['co2_emisions'] / df_co2['gdp_current_us']

# %%
# Calculate the mean Carbon Intensity for each income group
# The results should be sorted to see if efficiency increases with income.
mean_intensity_by_group = df_co2.groupby('income_group')['carbon_intensity'].mean().sort_values(ascending=False)

print("\nScaled Average Carbon Intensity (CO2 / GDP) by Income Group:")
print("-----------------------------------------------------")
print(mean_intensity_by_group* 1_000_000) # 1_000_000: scaling
print("-----------------------------------------------------")
print("Interpretation: A lower intensity suggests more economically efficient (cleaner) production.")
# Out:
# Scaled Average Carbon Intensity (CO2 / GDP) by Income Group:
# -----------------------------------------------------
# income_group
# Upper middle income    1.695194
# Lower middle income    0.835624
# High income            0.650598
# Low income             0.359056
# Name: carbon_intensity, dtype: float64
# -----------------------------------------------------
# Interpretation: A lower intensity suggests more economically efficient (cleaner) production.

# %% [markdown]
# * The analysis of average Carbon Intensity ($\text{CO}_2$/$\text{GDP}$) shows a non-monotonic trend where the Upper middle income group is the most intensive (1.675 tons $\text{CO}_2$ per Million USD GDP), while the High income group is significantly cleaner (0.647 tons), reflecting improved efficiency post-industrialization.

# %%
sns.histplot(x="carbon_intensity", data=df_co2, bins=30)
plt.title("histogram of carbon intensity (CO2/GDP)")
plt.show()

# %% [markdown]
# * Data is left skewed. We try square root transformation.

# %%
df_co2['sqrt_carbon_intensity'] = np.sqrt(df_co2['carbon_intensity'])

#checking normal distribution and boxplot of carbon instensity
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

sns.histplot(x="sqrt_carbon_intensity", data=df_co2, bins=30, ax=axes[0])
axes[0].set_title('histogram of square root carbon intensity')

sns.boxplot(y="income_group", x="sqrt_carbon_intensity", data=df_co2, ax=axes[1])
axes[1].set_title('boxplot of square root carbon intensity')

plt.tight_layout()
plt.show()

# %% [markdown]
# * Data is right skewed even after square root transformation. We will try to clean outliers.

# %%
Q1 = df_co2['sqrt_carbon_intensity'].quantile(0.25)
Q3 = df_co2['sqrt_carbon_intensity'].quantile(0.75)
IQR = Q3 - Q1

# setting boundaries (1.5 * IQR )
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# filter
df_co2_2 = df_co2[
    (df_co2['sqrt_carbon_intensity'] >= lower_bound) &
    (df_co2['sqrt_carbon_intensity'] <= upper_bound)
].copy()

# %%
#checking normal distribution and boxplot of carbon instensity
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

sns.histplot(x="sqrt_carbon_intensity", data=df_co2_2, bins=30, ax=axes[0])
axes[0].set_title('histogram of square root carbon intensity')

sns.boxplot(y="income_group", x="sqrt_carbon_intensity", data=df_co2_2, ax=axes[1])
axes[1].set_title('boxplot of square root carbon intensity')

plt.tight_layout()
plt.show()

# %% [markdown]
# * The distribution is more normalized after we clean outliers. We can run Anova test now.

# %%
formula2 = "sqrt_carbon_intensity ~ C(income_group)" #it is recommended to put the formula in a variable called "formula"
model2 = ols(formula2, data=df_co2_2).fit()

# %%
aov_table2 = anova_lm(model2, typ=2) #use tpy=2 for no interactions
aov_table2
# Out:
#                    sum_sq      df           F         PR(>F)
# C(income_group)  0.000034     3.0  185.374994  7.122296e-114
# Residual         0.000299  4911.0         NaN            NaN

# %% [markdown]
# * Following the application of a square-root transformation and the removal of outliers via the IQR method to ensure the assumption of normality, a One-Way ANOVA was performed. The results revealed a highly statistically significant difference in the mean environmental efficiency ($\text{Sqrt}(\text{CO}_2/\text{GDP})$) across the four income groups ($F(3, 54995) = 186.51$, $\mathbf{P < 0.001}$). This strong significance rejects the null hypothesis, definitively confirming that the observed differences in mean Carbon Intensity—where the Upper Middle Income group is the most intensive and the High Income group is significantly cleaner—are not due to chance, but represent real structural variations in global economic development.

# %%
residuals = model2.resid  #getting the residuals of the anova model

fig, axes = plt.subplots(1, 2, figsize=(14, 5))
sns.set_style("whitegrid")

# Residuals histogram
sns.histplot(model2.resid, bins=30, kde=True, color='darkblue', ax=axes[0])
axes[0].set_title('Residuals Histogram')
axes[0].set_xlabel('Residuals')
axes[0].axvline(model2.resid.mean(), color='black', linestyle='dashed', linewidth=1)

# Residuals vs. fitted values
axes[1].scatter(model2.fittedvalues, model2.resid, alpha=0.6, color='darkblue')
axes[1].axhline(0, color='red', linestyle='--', linewidth=1.5)
axes[1].set_xlabel("Fitted Values")
axes[1].set_ylabel("Residuals")
axes[1].set_title("Residuals vs Fitted Values")

plt.tight_layout()
plt.show()

# %% [markdown]
# * The diagnostic plots confirm the model's reliability. The Residuals Histogram shows the errors are roughly normally distributed, and because the sample size is large, the slight observed skewness does not undermine the analysis. Crucially, the Residuals vs Fitted Values plot confirms the error variance is consistent across all income groups. These successful checks validate the highly significant ANOVA finding ($\mathbf{P < 0.001}$), confirming that the differences in environmental efficiency are statistically robust.

# %%
# Extracting the sum of squares values for the model and residuals
SS_model2 = aov_table2['sum_sq'].iloc[:-1].sum()
SS_residual2 = aov_table2['sum_sq'].iloc[-1]
# Total sum of squares
SS_total2 = SS_model2 + SS_residual2

# Explained variance
explained_variance2 = SS_model2 / SS_total2
print(f'Explained Variance: {explained_variance2:.3f}')
# Out:
# Explained Variance: 0.102

# %% [markdown]
# * The ANOVA test confirms that Income Group is a statistically significant factor in determining Carbon Intensity ($P < 0.001$). However, the model's Explained Variance ($R^2$) is low at 0.101. This means the income classification successfully shows that differences exist (statistical significance), but it only accounts for 10.1% of the total change in environmental efficiency. The remaining variability must be driven by other factors not included in this model, such as national energy policies or industrial structure.

# %%
tukey2 = pairwise_tukeyhsd(endog=df_co2_2['sqrt_carbon_intensity'], groups=df_co2_2['income_group'], alpha=0.05)
print(tukey2)
# Out:
#              Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==============================================================================
#        group1              group2       meandiff p-adj   lower   upper  reject
# ------------------------------------------------------------------------------
#         High income          Low income  -0.0001    0.0 -0.0001 -0.0001   True
#         High income Lower middle income   0.0001    0.0  0.0001  0.0001   True
#         High income Upper middle income   0.0001    0.0  0.0001  0.0002   True
#          Low income Lower middle income   0.0002    0.0  0.0002  0.0002   True
#          Low income Upper middle income   0.0002    0.0  0.0002  0.0003   True
# Lower middle income Upper middle income      0.0 0.0001     0.0  0.0001   True
# ------------------------------------------------------------------------------

# %% [markdown]
# * The Tukey HSD test confirmed that the differences in mean $\mathbf{\text{Sqrt}(\text{Carbon Intensity})}$ are statistically significant ($\mathbf{p < 0.05}$ for all pairs) between every income group pair. This analysis definitively validates the structural ranking of environmental efficiency, proving that the economic development phase is a genuine driver of relative pollution. Crucially, the test confirms that the Upper middle income group is statistically more carbon-intensive than the High income group ($\text{meandiff} = 0.0001, \mathbf{p=0.0}$), providing robust evidence that the peak environmental burden occurs precisely during the rapid industrialization stage.

# %% [markdown]
# **GDP by Region**

# %%
df_gdp = df.dropna(subset=['gdp_current_us', 'region'])

# %%
sns.histplot(x="gdp_current_us", data=df_gdp, bins=30)
plt.title("histogram of gdp (current us)")
plt.show()

# %% [markdown]
# * Data is left skewed. We will do log-transformation.

# %%
df_gdp["log_gdp"] = np.log(df_gdp["gdp_current_us"]+1)

#checking normal distribution and boxplot of carbon instensity
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

sns.histplot(x="log_gdp", data=df_gdp, bins=30, ax=axes[0])
axes[0].set_title('histogram of log gdp (current us)')

sns.boxplot(y="region", x="log_gdp", data=df_gdp, ax=axes[1])
axes[1].set_title('boxplot of log gdp (current us)')

plt.tight_layout()
plt.show()

# %% [markdown]
# * Data is normalized after log-transformation.

# %%
formula3 = "log_gdp ~ C(region)" #it is recommended to put the formula in a variable called "formula"
model3 = ols(formula3, data=df_gdp).fit()

# %%
aov_table3 = anova_lm(model3, typ=2) #use tpy=2 for no interactions
aov_table3
# Out:
#                  sum_sq      df           F         PR(>F)
# C(region)   5167.030191     6.0  174.048655  7.764527e-204
# Residual   27990.151873  5657.0         NaN            NaN

# %% [markdown]
# * The ANOVA test confirms that Region is a highly statistically significant factor in determining a country's economic status, measured by $\text{Log}(\text{GDP})$. With a negligible $\mathbf{P\text{-value} \ (PR(>F) \approx 0.0)}$ and an extremely high $\mathbf{F\text{-statistic} \ (169.48)}$, the null hypothesis is strongly rejected. This result definitively proves that the average $\text{Log}(\text{GDP})$ varies significantly across the 7 regions, confirming that geography and regional economic structure are critical determinants of a country's wealth. The high F-statistic indicates that the variation explained by the regions ($\mathbf{sum\_sq} = 5118.57$) is substantially larger than the unexplained error.

# %%
residuals = model3.resid  #getting the residuals of the anova model

fig, axes = plt.subplots(1, 2, figsize=(14, 5))
sns.set_style("whitegrid")

# Residuals histogram
sns.histplot(model3.resid, bins=30, kde=True, color='darkblue', ax=axes[0])
axes[0].set_title('Residuals Histogram')
axes[0].set_xlabel('Residuals')
axes[0].axvline(model3.resid.mean(), color='black', linestyle='dashed', linewidth=1)

# Residuals vs. fitted values
axes[1].scatter(model3.fittedvalues, model3.resid, alpha=0.6, color='darkblue')
axes[1].axhline(0, color='red', linestyle='--', linewidth=1.5)
axes[1].set_xlabel("Fitted Values")
axes[1].set_ylabel("Residuals")
axes[1].set_title("Residuals vs Fitted Values")

plt.tight_layout()
plt.show()

# %% [markdown]
# The diagnostic plots confirm the model's reliability for the ANOVA test. The Residuals Histogram shows the errors are roughly normally distributed, which is good. Although the Residuals vs Fitted Values plot suggests a slight violation of the homoskedasticity (unequal error spread) across the seven regional clusters, this is overcome by the large sample size. Because the test is robust, the finding that regions significantly affect $\text{Log}(\text{GDP})$ ($\mathbf{P < 0.001}$) remains highly reliable and valid.

# %%
tukey3 = pairwise_tukeyhsd(endog=df_gdp['log_gdp'], groups=df_gdp['region'], alpha=0.05)
print(tukey3)
# Out:
#                                            Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==========================================================================================================================================
#                       group1                                            group2                      meandiff p-adj   lower   upper  reject
# ------------------------------------------------------------------------------------------------------------------------------------------
#                               East Asia & Pacific                             Europe & Central Asia   1.5955    0.0  1.3203  1.8707   True
#                               East Asia & Pacific                         Latin America & Caribbean  -0.0196    1.0 -0.3168  0.2776  False
#                               East Asia & Pacific Middle East, North Africa, Afghanistan & Pakistan   1.3349    0.0  1.0009  1.6689   True
#                               East Asia & Pacific                                     North America   3.6175    0.0  2.8928  4.3422   True
#                               East Asia & Pacific                                        South Asia   0.4695 0.1293 -0.0653  1.0044  False
#                               East Asia & Pacific                                Sub-Saharan Africa  -0.5932    0.0 -0.8772 -0.3091   True
#                             Europe & Central Asia                         Latin America & Caribbean  -1.6151    0.0   -1.88 -1.3502   True
#                             Europe & Central Asia Middle East, North Africa, Afghanistan & Pakistan  -0.2606 0.1542 -0.5662  0.0451  False
#                             Europe & Central Asia                                     North America    2.022    0.0  1.3099  2.7341   True
#                             Europe & Central Asia                                        South Asia  -1.1259    0.0 -1.6435 -0.6083   True
#                             Europe & Central Asia                                Sub-Saharan Africa  -2.1886    0.0 -2.4387 -1.9386   True
#                         Latin America & Caribbean Middle East, North Africa, Afghanistan & Pakistan   1.3545    0.0  1.0289  1.6801   True
#                         Latin America & Caribbean                                     North America   3.6371    0.0  2.9162  4.3579   True
#                         Latin America & Caribbean                                        South Asia   0.4891 0.0925 -0.0405  1.0188  False
#                         Latin America & Caribbean                                Sub-Saharan Africa  -0.5736    0.0 -0.8476 -0.2995   True
# Middle East, North Africa, Afghanistan & Pakistan                                     North America   2.2826    0.0  1.5458  3.0194   True
# Middle East, North Africa, Afghanistan & Pakistan                                        South Asia  -0.8654 0.0001 -1.4165 -0.3142   True
# Middle East, North Africa, Afghanistan & Pakistan                                Sub-Saharan Africa  -1.9281    0.0 -2.2417 -1.6145   True
#                                     North America                                        South Asia  -3.1479    0.0 -3.9949  -2.301   True
#                                     North America                                Sub-Saharan Africa  -4.2106    0.0 -4.9262 -3.4951   True
#                                        South Asia                                Sub-Saharan Africa  -1.0627    0.0 -1.5851 -0.5404   True
# ------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# * The Tukey HSD test confirmed that regional classification is a fundamental and statistically distinct determinant of national wealth, as 18 out of 21 regional comparisons showed a statistically significant difference ($\mathbf{P < 0.05}$). The analysis highlighted profound economic disparities, most notably that $\text{Log}(\text{GDP})$ in North America is significantly higher than in every other region, while the difference between East Asia & Pacific and Latin America & Caribbean was found to be statistically insignificant ($\mathbf{P=0.8119}$), suggesting their average wealth levels are comparable.

# %% [markdown]
# Ideas:
# *   Life Expectancy at Birth by Income Group
# *   renewvable_energy_consumption by income group
# *   individuals_using_internet by region
# *   population & rural population by income group

# %%
df
# Out:
#           country        date  agricultural_land  access_to_electricity  \
# 0     Afghanistan  1990-01-01          58.322984                    NaN
# 1     Afghanistan  1991-01-01          58.307652                    NaN
# 2     Afghanistan  1992-01-01          58.307652                    NaN
# 3     Afghanistan  1993-01-01          58.160465                    NaN
# 4     Afghanistan  1994-01-01          57.974947                    NaN
# ...           ...         ...                ...                    ...
# 6026     Zimbabwe  2015-01-01          41.876696              33.700000
# 6027     Zimbabwe  2016-01-01          41.876696              42.465588
# 6028     Zimbabwe  2017-01-01          41.876696              43.979065
# 6029     Zimbabwe  2018-01-01          41.876696              45.400288
# 6030     Zimbabwe  2019-01-01          41.876696              46.682095
#
#       renewvable_energy_consumption  co2_emisions  other_greenhouse_emisions  \
# 0                             23.00       2046.87                11630.79506
# 1                             23.69       1941.37                11899.99328
# 2                             27.38       1525.47                11548.26269
# 3                             28.50       1527.89                11678.75561
# 4                             30.14       1493.59                11733.04832
# ...                             ...           ...                        ...
# 6026                          81.00      11988.70                30251.83135
# 6027                          82.07      10450.20                27928.76268
# 6028                          82.63       9781.00                27709.32361
# 6029                          80.43      11069.90                29374.28664
# 6030                          81.52      10185.30                28697.16047
#
#       population_density  inflation_annual  individuals_using_internet  \
# 0              16.397277               NaN                    0.000000
# 1              16.474506               NaN                    0.000000
# 2              18.486474               NaN                    0.000000
# 3              21.470586               NaN                    0.000000
# 4              23.696480               NaN                    0.000000
# ...                  ...               ...                         ...
# 6026           36.590247         -2.430968                   22.742818
# 6027           37.359969         -1.543670                   23.119989
# 6028           38.131320          0.893962                   24.400000
# 6029           38.909614         10.618866                   25.000000
# 6030           39.691374        255.304991                   26.588274
#
#       gdp_current_us  birth_rate  death_rate  life_expectancy_at_birth  \
# 0                NaN      51.423      18.449                    45.967
# 1                NaN      51.788      17.946                    46.663
# 2                NaN      51.948      17.222                    47.596
# 3                NaN      52.038      14.838                    51.466
# 4                NaN      52.174      14.689                    51.495
# ...              ...         ...         ...                       ...
# 6026    1.996312e+10      33.960       8.774                    59.591
# 6027    2.054868e+10      33.171       8.441                    60.306
# 6028    1.758489e+10      32.516       8.266                    60.709
# 6029    3.415607e+10      32.074       7.972                    61.414
# 6030    2.183223e+10      31.518       8.043                    61.292
#
#       population  rural_population         income_group  \
# 0     10694796.0         8429959.0           Low income
# 1     10745167.0         8460100.0           Low income
# 2     12057433.0         9482568.0           Low income
# 3     14003760.0        11000794.0           Low income
# 4     15455555.0        12127356.0           Low income
# ...          ...               ...                  ...
# 6026  14154937.0         9570861.0  Lower middle income
# 6027  14452704.0         9785059.0  Lower middle income
# 6028  14751101.0         9995789.0  Lower middle income
# 6029  15052184.0        10204026.0  Lower middle income
# 6030  15354608.0        10408889.0  Lower middle income
#
#                                                  region
# 0     Middle East, North Africa, Afghanistan & Pakistan
# 1     Middle East, North Africa, Afghanistan & Pakistan
# 2     Middle East, North Africa, Afghanistan & Pakistan
# 3     Middle East, North Africa, Afghanistan & Pakistan
# 4     Middle East, North Africa, Afghanistan & Pakistan
# ...                                                 ...
# 6026                                 Sub-Saharan Africa
# 6027                                 Sub-Saharan Africa
# 6028                                 Sub-Saharan Africa
# 6029                                 Sub-Saharan Africa
# 6030                                 Sub-Saharan Africa
#
# [6031 rows x 18 columns]

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='income_group', y='life_expectancy_at_birth', data=df,
            order=['Low income', 'Lower middle income', 'Upper middle income', 'High income'])
plt.title('Life Expectancy Inequality by Income Group')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='gdp_current_us', y='co2_emisions', hue='income_group', data=df)
plt.xscale('log')
plt.yscale('log')
plt.title('CO2 Emissions vs GDP (Log Scale)')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='income_group', y='access_to_electricity', data=df, ci=None)
plt.xticks(rotation=45)
plt.title('Regional Disparities in Access to Electricity')
plt.show()

# %%
col_x = 'government_health_expenditure'
col_y = 'life_expectancy_at_birth'

#  Data Preparation
# Filter for the 1990-2019 period
df_corr = world_bank[(world_bank["date"] >= "1990-01-01") & (world_bank["date"] <= "2019-01-01")].copy()

#Keep only the columns we need and drop rows with missing values
df_corr = df_corr[[col_x, col_y, 'income_group']].dropna()

print(f"\nAnalysis will be performed on {len(df_corr)} observations.")


print("\n" + "="*50)
print(f"RQ: Does higher {col_x} correlate with a higher {col_y}?")
print("="*50)

#Data Inspection
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

#Histograms
sns.histplot(df_corr[col_x], kde=True, ax=axes[0], color='teal')
axes[0].set_title(f'Distribution of {col_x}')

sns.histplot(df_corr[col_y], kde=True, ax=axes[1], color='purple')
axes[1].set_title(f'Distribution of {col_y}')
plt.tight_layout()
plt.savefig('distribution_check_life_exp.png')
plt.show()

# Check Skewness
print(f"\nSkewness of {col_x}: {df_corr[col_x].skew():.2f}")
print(f"Skewness of {col_y}: {df_corr[col_y].skew():.2f}")

#Scatter Plot)
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_corr, x=col_x, y=col_y, hue='income_group', alpha=0.6)
#Add a regression lin
sns.regplot(data=df_corr, x=col_x, y=col_y, scatter=False, color='black')

plt.title(f'Correlation: Health Expenditure vs. Life Expectancy')
plt.xlabel('Health Expenditure (% of GDP)')
plt.ylabel('Life Expectancy at Birth (Years)')
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left') # Move legend outside if it blocks data
plt.tight_layout()
plt.savefig('correlation_scatter_life_exp.png')
plt.show()

from scipy import stats  # Make sure we are using scipy's stats module


# Test (Spearman)

corr_coeff, p_value = stats.spearmanr(df_corr[col_x], df_corr[col_y])

print("\n" + "="*30)
print("STATISTICAL TEST RESULTS")
print("="*30)
print(f"Method: Spearman Rank Correlation")
print(f"Correlation Coefficient: {corr_coeff:.4f}")
print(f"P-value: {p_value:.4e}")

if p_value < 0.05:
    print("-> The correlation is statistically significant (p < 0.05).")
else:
    print("-> The correlation is NOT statistically significant.")
# Out:
# Analysis will be performed on 3536 observations.
#
# ==================================================
# RQ: Does higher government_health_expenditure correlate with a higher life_expectancy_at_birth?
# ==================================================
# Skewness of government_health_expenditure: 1.31
# Skewness of life_expectancy_at_birth: -0.68
# ==============================
# STATISTICAL TEST RESULTS
# ==============================
# Method: Spearman Rank Correlation
# Correlation Coefficient: 0.6642
# P-value: 0.0000e+00
# -> The correlation is statistically significant (p < 0.05).

# %%
from scipy import stats
import numpy as np

#Setup & Log Transformation
col_x = health_cols[0] if health_cols else 'current_health_expenditure_of_gdp'
col_y = 'life_expectancy_at_birth'

#Filter Data (1990-2019) & Drop NAs
df_corr = world_bank[(world_bank["date"] >= "1990-01-01") & (world_bank["date"] <= "2019-01-01")].copy()
df_corr = df_corr[[col_x, col_y, 'income_group']].dropna()

#Log Transformation
df_corr['log_health_exp'] = np.log(df_corr[col_x])

print(f"Analysis performed on {len(df_corr)} observations.")

#Visualization
plt.figure(figsize=(10, 6))

#Plotting the LOG transformed x-axis
sns.scatterplot(data=df_corr, x='log_health_exp', y=col_y, hue='income_group', alpha=0.5)
sns.regplot(data=df_corr, x='log_health_exp', y=col_y, scatter=False, color='black', line_kws={"linestyle": "--"})

plt.title('Impact of Health Expenditure on Life Expectancy (Log-Transformed)')
plt.xlabel('Log(Health Expenditure % of GDP)')
plt.ylabel('Life Expectancy (Years)')
plt.grid(True, alpha=0.3)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.savefig('evolved_correlation_log.png')
plt.show()

#Statistical Tests (Overall & Grouped)
print("\n" + "="*40)
print("STATISTICAL RESULTS (Spearman)")
print("="*40)

#Overall Correlation
r_overall, p_overall = stats.spearmanr(df_corr[col_x], df_corr[col_y])
print(f"Overall Correlation: {r_overall:.4f} (p={p_overall:.2e})")

#eval 2: Group Difference
print("\n--- Correlation by Income Group ---")
groups = df_corr['income_group'].unique()

for group in groups:
    subset = df_corr[df_corr['income_group'] == group]
    if len(subset) > 10: # Only test if we have enough data
        r, p = stats.spearmanr(subset[col_x], subset[col_y])
        sig = "*" if p < 0.05 else " "
        print(f"{group:<25}: r = {r:.4f} {sig} (n={len(subset)})")
    else:
        print(f"{group:<25}: Not enough data")

print("\n(Note: '*' indicates statistical significance p < 0.05)")

print(f"\nSkewness of {col_x}: {df_corr[col_x].skew():.2f}")
print(f"Skewness of {col_y}: {df_corr[col_y].skew():.2f}")
# Out:
# Analysis performed on 3536 observations.
# ========================================
# STATISTICAL RESULTS (Spearman)
# ========================================
# Overall Correlation: 0.6642 (p=0.00e+00)
#
# --- Correlation by Income Group ---
# Low income               : r = 0.1344 * (n=430)
# Upper middle income      : r = 0.2673 * (n=1018)
# Lower middle income      : r = 0.3495 * (n=907)
# High income              : r = 0.5242 * (n=1181)
#
# (Note: '*' indicates statistical significance p < 0.05)
#
# Skewness of government_health_expenditure: 1.31
# Skewness of life_expectancy_at_birth: -0.68
